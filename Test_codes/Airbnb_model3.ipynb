# %%
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV, LassoCV, Lasso, Ridge
from sklearn.model_selection import train_test_split, GridSearchCV, KFold , cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

import statsmodels.api as sm
import statsmodels.formula.api as smf

import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import datetime

plt.style.use('seaborn')
sns.set_palette("husl")
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
abnb_df = pd.read_csv('data/listing_final.csv')
abnb_df = abnb_df.drop(columns= ['Unnamed: 0'])

# %%
abnb_df.rename(index = str, columns ={'f': 'not_superhost', 't': 'is_superhost', 'zvi' :'rent_index', 'strict_14_with_grace_period' :'strict_14',\
                                     'super_strict_30': 'strict_30', 'super_strict_60': 'strict_60'}, inplace = True)

abnb_df.rename(str.lower , axis ='columns', inplace=True)

# %%
abnb_df.columns
# Out:
# Index(['host_response_rate', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'price', 'security_deposit', 'cleaning_fee', 'guests_included',
#        'extra_people', 'availability_60', 'availability_90',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'rent_index', 'number_of_days_as_host',
#        'number_of_amenities', 'review_period', 'not_superhost', 'is_superhost',
#        'moderate', 'strict', 'strict_14', 'strict_30', 'strict_60'],
#       dtype='object')

# %%
X = abnb_df[['host_response_rate', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
       'security_deposit', 'cleaning_fee', 'guests_included',
       'extra_people',
       'number_of_reviews', 'review_scores_cleanliness','rent_index', 'number_of_days_as_host',
       'number_of_amenities', 'review_period', 'not_superhost', 'is_superhost']]
y = abnb_df['price']
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.3, random_state = 42)

# %%
degree = 4
model_poly1 = make_pipeline(PolynomialFeatures(degree), LinearRegression())
model_poly1.fit(X, y)
s = model_poly1.score(X, y)
r = np.sqrt(mean_squared_error(y, model_poly1.predict(X)))
print('R^2:', s, 'RMSE:' , r)
# Out:
# R^2: 0.8941168048520444 RMSE: 38.072107400972435

# %%
model_poly1.get_params()
# Out:
# {'memory': None,
#  'steps': [('polynomialfeatures',
#    PolynomialFeatures(degree=4, include_bias=True, interaction_only=False)),
#   ('linearregression',
#    LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))],
#  'polynomialfeatures': PolynomialFeatures(degree=4, include_bias=True, interaction_only=False),
#  'linearregression': LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#  'polynomialfeatures__degree': 4,
#  'polynomialfeatures__include_bias': True,
#  'polynomialfeatures__interaction_only': False,
#  'linearregression__copy_X': True,
#  'linearregression__fit_intercept': True,
#  'linearregression__n_jobs': 1,
#  'linearregression__normalize': False}

# %%
poly1=PolynomialFeatures(4)
X_poly=poly1.fit_transform(X)

model = LinearRegression()

model.fit(X_poly,y)
betas = model.coef_
# Out:
# betas [ 1.87409696e-05 -6.48585703e+01 -6.33276503e+00 ...  0.00000000e+00
#   0.00000000e+00  4.24897986e-01]

# %%
model.intercept_
betas = model.coef_
len(betas)
# Out:
# 5985

# %%
['host_response_rate', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
       'security_deposit', 'cleaning_fee', 'guests_included',
       'extra_people',
       'number_of_reviews', 'review_scores_cleanliness','rent_index', 'number_of_days_as_host',
       'number_of_amenities', 'review_period', 'not_superhost', 'is_superhost']

# %% [markdown]
# ### Statsmodel.api

# %%
# Define the model
lm1 = smf.ols('price ~ host_response_rate + accommodates + bathrooms + bedrooms + beds + security_deposit + cleaning_fee + guests_included + extra_people + number_of_reviews + review_scores_cleanliness + rent_index + number_of_days_as_host + number_of_amenities + review_period + not_superhost + is_superhost', data = abnb_df)

# Fit your model to your training set
fit_lm1 = lm1.fit()

# Print summary statistics of the model's performance
fit_lm1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     274.9
# Date:                Thu, 11 Oct 2018   Prob (F-statistic):               0.00
# Time:                        00:30:24   Log-Likelihood:                -45857.
# No. Observations:                7715   AIC:                         9.175e+04
# Df Residuals:                    7697   BIC:                         9.188e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                  -114.0062     92.969     -1.226      0.220    -296.251      68.239
# host_response_rate           -0.1483      0.035     -4.251      0.000      -0.217      -0.080
# accommodates                 16.8625      0.730     23.102      0.000      15.432      18.293
# bathrooms                    13.2872      1.711      7.764      0.000       9.932      16.642
# bedrooms                      9.0213      1.798      5.017      0.000       5.497      12.546
# beds                         -7.5325      1.095     -6.876      0.000      -9.680      -5.385
# security_deposit              0.0062      0.007      0.885      0.376      -0.008       0.020
# cleaning_fee                  0.5364      0.029     18.731      0.000       0.480       0.592
# guests_included              -1.3198      0.808     -1.634      0.102      -2.903       0.264
# extra_people                  0.0628      0.045      1.401      0.161      -0.025       0.151
# number_of_reviews            -0.2898      0.029     -9.918      0.000      -0.347      -0.233
# review_scores_cleanliness    -1.3923      0.358     -3.885      0.000      -2.095      -0.690
# rent_index                    0.0493      0.004     11.055      0.000       0.041       0.058
# number_of_days_as_host       -0.0038      0.002     -2.233      0.026      -0.007      -0.000
# number_of_amenities           0.4970      0.111      4.483      0.000       0.280       0.714
# review_period                 0.0119      0.003      3.659      0.000       0.006       0.018
# not_superhost                72.5216     92.688      0.782      0.434    -109.173     254.216
# is_superhost                 65.9770     92.682      0.712      0.477    -115.704     247.658
# ==============================================================================
# Omnibus:                     4341.068   Durbin-Watson:                   1.610
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            76199.529
# Skew:                           2.326   Prob(JB):                         0.00
# Kurtosis:                      17.676   Cond. No.                     3.48e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.48e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
fit_poly = sm.GLS(y, X_poly).fit()

# %%
fit_poly.summary().tables[0]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
fit_poly.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
import pprint
poly_features = PolynomialFeatures(4)
poly_ft = poly_features.fit_transform(X)
poly_model3 = LinearRegression()
poly_model3.fit(poly_ft, y)
poly_model3_coef = poly_model3.coef_
pprint.pprint(sorted(dict(zip(poly_features.get_feature_names(list(X.columns)),poly_model3_coef)).items(), key=lambda kv:kv[1]))
# Out:
# {'1': 1.8740969633705772e-05,
#  'accommodates': -6.332765028575909,
#  'accommodates bathrooms': -18.496773721648644,
#  'accommodates bathrooms bedrooms': 34.812550132481974,
#  'accommodates bathrooms bedrooms beds': -9.482157211417293,
#  'accommodates bathrooms bedrooms cleaning_fee': -0.16344477671609775,
#  'accommodates bathrooms bedrooms extra_people': -0.9953307691028829,
#  'accommodates bathrooms bedrooms guests_included': 16.344753516561745,
#  'accommodates bathrooms bedrooms is_superhost': 56.820162119529606,
#  'accommodates bathrooms bedrooms not_superhost': -22.007251326783972,
#  'accommodates bathrooms bedrooms number_of_amenities': 0.7076899615696582,
#  'accommodates bathrooms bedrooms number_of_days_as_host': 0.04712025486595778,
#  'accommodates bathrooms bedrooms number_of_reviews': -0.41741862641054245,
#  'accommodates bathrooms bedrooms rent_index': 0.0015238153698562895,
#  'accommodates bathrooms bedrooms review_period': -0.06156922712794412,
#  'accommodates bathrooms bedrooms review_scores_cleanliness': 1.8796948716407111,
#  'accommodates bathrooms bedrooms security_deposit': 0.09039700626748606,
#  'accommodates bathrooms bedrooms^2': -15.86512928177107,
#  'accommodates bathrooms beds': -41.24391227976281,
#  'accommodates bathrooms beds cleaning_fee': 0.38974462722110964,
#  'accommodates bathrooms beds extra_people': -0.7464991875350595,
#  'accommodates bathrooms beds guests_included': -1.8385548592556655,
#  'accommodates bathrooms beds is_superhost': -40.15734667295217,
#  'accommodates bathrooms beds not_superhost': -1.085997432557341,
#  'accommodates bathrooms beds number_of_amenities': 0.6516515179403374,
#  'accommodates bathrooms beds number_of_days_as_host': 0.009038718591960515,
#  'accommodates bathrooms beds number_of_reviews': 0.003486784486440063,
#  'accommodates bathrooms beds rent_index': -0.0019296171930698071,
#  'accommodates bathrooms beds review_period': 0.03857161213074652,
#  'accommodates bathrooms beds review_scores_cleanliness': 0.46633211335790176,
#  'accommodates bathrooms beds security_deposit': 0.04879483158482031,
#  'accommodates bathrooms beds^2': -7.220295304996891,
#  'accommodates bathrooms cleaning_fee': -1.9374149188959928,
#  'accommodates bathrooms cleaning_fee extra_people': 0.025458478317772346,
#  'accommodates bathrooms cleaning_fee guests_included': -0.10384794637590025,
#  'accommodates bathrooms cleaning_fee is_superhost': -1.349221856182273,
#  'accommodates bathrooms cleaning_fee not_superhost': -0.5895099274392337,
#  'accommodates bathrooms cleaning_fee number_of_amenities': 0.02871447945491966,
#  'accommodates bathrooms cleaning_fee number_of_days_as_host': 0.00041868405593046236,
#  'accommodates bathrooms cleaning_fee number_of_reviews': -0.018590422573588897,
#  'accommodates bathrooms cleaning_fee rent_index': 0.0006630045145549572,
#  'accommodates bathrooms cleaning_fee review_period': -0.00033328108976589984,
#  'accommodates bathrooms cleaning_fee review_scores_cleanliness': -0.0723937026789761,
#  'accommodates bathrooms cleaning_fee^2': -0.006040404983746988,
#  'accommodates bathrooms extra_people': -1.3862218097682153,
#  'accommodates bathrooms extra_people is_superhost': -1.2495203556915169,
#  'accommodates bathrooms extra_people not_superhost': -0.13611296090626893,
#  'accommodates bathrooms extra_people number_of_amenities': -0.053847761357679096,
#  'accommodates bathrooms extra_people number_of_days_as_host': -0.0011911769912329338,
#  'accommodates bathrooms extra_people number_of_reviews': 0.04488313362377543,
#  'accommodates bathrooms extra_people rent_index': 5.9105892433445344e-05,
#  'accommodates bathrooms extra_people review_period': 0.00029649991103100756,
#  'accommodates bathrooms extra_people review_scores_cleanliness': 0.5158614944177691,
#  'accommodates bathrooms extra_people^2': -0.03007277599045318,
#  'accommodates bathrooms guests_included': -24.71731359988065,
#  'accommodates bathrooms guests_included extra_people': 0.46630693527269007,
#  'accommodates bathrooms guests_included is_superhost': -13.494877422811056,
#  'accommodates bathrooms guests_included not_superhost': -11.222805111924963,
#  'accommodates bathrooms guests_included number_of_amenities': -0.4376759895079487,
#  'accommodates bathrooms guests_included number_of_days_as_host': 0.007192234146801697,
#  'accommodates bathrooms guests_included number_of_reviews': -0.15688265537749008,
#  'accommodates bathrooms guests_included rent_index': 0.01302094914025017,
#  'accommodates bathrooms guests_included review_period': 0.01858484774358039,
#  'accommodates bathrooms guests_included review_scores_cleanliness': -2.9076256377255296,
#  'accommodates bathrooms guests_included^2': -3.2414857552238066,
#  'accommodates bathrooms is_superhost': 30.097694754683367,
#  'accommodates bathrooms is_superhost^2': 30.09812907127397,
#  'accommodates bathrooms not_superhost': -48.8633155838176,
#  'accommodates bathrooms not_superhost is_superhost': 1.0593871422465151e-08,
#  'accommodates bathrooms not_superhost^2': -48.86393599607517,
#  'accommodates bathrooms number_of_amenities': 0.040858807572655934,
#  'accommodates bathrooms number_of_amenities is_superhost': 0.1991023415206351,
#  'accommodates bathrooms number_of_amenities not_superhost': -0.159469962051419,
#  'accommodates bathrooms number_of_amenities review_period': -0.0022564707727049495,
#  'accommodates bathrooms number_of_amenities^2': 0.05026387361760883,
#  'accommodates bathrooms number_of_days_as_host': 0.02542233932502123,
#  'accommodates bathrooms number_of_days_as_host is_superhost': 0.007050613716937027,
#  'accommodates bathrooms number_of_days_as_host not_superhost': 0.018653178617804644,
#  'accommodates bathrooms number_of_days_as_host number_of_amenities': 1.0597067464493793e-05,
#  'accommodates bathrooms number_of_days_as_host review_period': 3.289009811592477e-05,
#  'accommodates bathrooms number_of_days_as_host^2': -1.2922049752484338e-05,
#  'accommodates bathrooms number_of_reviews': -2.476639034520401,
#  'accommodates bathrooms number_of_reviews is_superhost': -1.6505392195510487,
#  'accommodates bathrooms number_of_reviews not_superhost': -0.8255630709877431,
#  'accommodates bathrooms number_of_reviews number_of_amenities': 0.005487167563312991,
#  'accommodates bathrooms number_of_reviews number_of_days_as_host': 0.000856990457539173,
#  'accommodates bathrooms number_of_reviews rent_index': 0.0009203576152980918,
#  'accommodates bathrooms number_of_reviews review_period': -9.170685813000811e-05,
#  'accommodates bathrooms number_of_reviews review_scores_cleanliness': -0.12566820979064658,
#  'accommodates bathrooms number_of_reviews^2': -0.0064297933701438666,
#  'accommodates bathrooms rent_index': -0.14664571741961954,
#  'accommodates bathrooms rent_index is_superhost': -0.06457073280670535,
#  'accommodates bathrooms rent_index not_superhost': -0.0829302699273852,
#  'accommodates bathrooms rent_index number_of_amenities': -0.0027995860435633523,
#  'accommodates bathrooms rent_index number_of_days_as_host': -3.460274752559397e-05,
#  'accommodates bathrooms rent_index review_period': -0.000107032995434582,
#  'accommodates bathrooms rent_index^2': 0.00012362956515246207,
#  'accommodates bathrooms review_period': -0.018379251581783492,
#  'accommodates bathrooms review_period is_superhost': 0.04695816534130499,
#  'accommodates bathrooms review_period not_superhost': -0.06443940595584377,
#  'accommodates bathrooms review_period^2': 9.215763362663361e-06,
#  'accommodates bathrooms review_scores_cleanliness': -15.61300154523809,
#  'accommodates bathrooms review_scores_cleanliness is_superhost': -23.417579549998266,
#  'accommodates bathrooms review_scores_cleanliness not_superhost': 7.804315500873596,
#  'accommodates bathrooms review_scores_cleanliness number_of_amenities': 0.21302588655290972,
#  'accommodates bathrooms review_scores_cleanliness number_of_days_as_host': -0.002964743976627266,
#  'accommodates bathrooms review_scores_cleanliness rent_index': 0.01697846733952344,
#  'accommodates bathrooms review_scores_cleanliness review_period': 0.07123819082604906,
#  'accommodates bathrooms review_scores_cleanliness^2': -1.6897159093771597,
#  'accommodates bathrooms security_deposit': -0.03167780108429328,
#  'accommodates bathrooms security_deposit cleaning_fee': 0.0008232341524596907,
#  'accommodates bathrooms security_deposit extra_people': -0.003138456671277077,
#  'accommodates bathrooms security_deposit guests_included': 0.03215322867508042,
#  'accommodates bathrooms security_deposit is_superhost': -0.049755068619666436,
#  'accommodates bathrooms security_deposit not_superhost': 0.017670002337233603,
#  'accommodates bathrooms security_deposit number_of_amenities': -0.011946699320736203,
#  'accommodates bathrooms security_deposit number_of_days_as_host': -8.607475258200972e-05,
#  'accommodates bathrooms security_deposit number_of_reviews': 0.008034423654520862,
#  'accommodates bathrooms security_deposit rent_index': 0.00026205375383174507,
#  'accommodates bathrooms security_deposit review_period': -0.00039089603919318977,
#  'accommodates bathrooms security_deposit review_scores_cleanliness': -0.008930556709890552,
#  'accommodates bathrooms security_deposit^2': 0.00010217208767341125,
#  'accommodates bathrooms^2': -12.197921757065675,
#  'accommodates bathrooms^2 bedrooms': 1.0503625611701786,
#  'accommodates bathrooms^2 beds': 12.819699144410302,
#  'accommodates bathrooms^2 cleaning_fee': 0.3945064133174837,
#  'accommodates bathrooms^2 extra_people': -0.5503096031191305,
#  'accommodates bathrooms^2 guests_included': 5.712782768624263,
#  'accommodates bathrooms^2 is_superhost': 17.941931622024075,
#  'accommodates bathrooms^2 not_superhost': -30.138944563538853,
#  'accommodates bathrooms^2 number_of_amenities': -1.0563852364994102,
#  'accommodates bathrooms^2 number_of_days_as_host': -0.0066462805674223045,
#  'accommodates bathrooms^2 number_of_reviews': 0.013896062018466443,
#  'accommodates bathrooms^2 rent_index': 0.06111650374174359,
#  'accommodates bathrooms^2 review_period': -0.03359668337117339,
#  'accommodates bathrooms^2 review_scores_cleanliness': -2.586703824655709,
#  'accommodates bathrooms^2 security_deposit': -0.013249188072981987,
#  'accommodates bathrooms^3': -9.497969145281811,
#  'accommodates bedrooms': -54.888905738159416,
#  'accommodates bedrooms beds': -38.75564545577246,
#  'accommodates bedrooms beds cleaning_fee': -0.5083619102743964,
#  'accommodates bedrooms beds extra_people': 0.1783299621207592,
#  'accommodates bedrooms beds guests_included': 0.1299908988970858,
#  'accommodates bedrooms beds is_superhost': -2.9887000955136176,
#  'accommodates bedrooms beds not_superhost': -35.767061985921345,
#  'accommodates bedrooms beds number_of_amenities': 1.141642091212249,
#  'accommodates bedrooms beds number_of_days_as_host': -0.013568085696019687,
#  'accommodates bedrooms beds number_of_reviews': -0.3597419437135535,
#  'accommodates bedrooms beds rent_index': 0.019040400928918587,
#  'accommodates bedrooms beds review_period': -0.006266171758663157,
#  'accommodates bedrooms beds review_scores_cleanliness': 0.43887632104192814,
#  'accommodates bedrooms beds security_deposit': -0.053280598608154386,
#  'accommodates bedrooms beds^2': -1.96530137187796,
#  'accommodates bedrooms cleaning_fee': 0.16545547726877097,
#  'accommodates bedrooms cleaning_fee extra_people': -0.035509534418461434,
#  'accommodates bedrooms cleaning_fee guests_included': 0.22470607284286737,
#  'accommodates bedrooms cleaning_fee is_superhost': 0.47386376586303963,
#  'accommodates bedrooms cleaning_fee not_superhost': -0.30858207579597224,
#  'accommodates bedrooms cleaning_fee number_of_amenities': -0.02459598422468398,
#  'accommodates bedrooms cleaning_fee number_of_days_as_host': -0.0004238844073449132,
#  'accommodates bedrooms cleaning_fee number_of_reviews': 0.017931097330019644,
#  'accommodates bedrooms cleaning_fee rent_index': -0.00022204993633255307,
#  'accommodates bedrooms cleaning_fee review_period': -0.0020042187359902105,
#  'accommodates bedrooms cleaning_fee review_scores_cleanliness': 0.026598593149989903,
#  'accommodates bedrooms cleaning_fee^2': 0.00932312428284499,
#  'accommodates bedrooms extra_people': 4.78239835586001,
#  'accommodates bedrooms extra_people is_superhost': 3.1778283133309317,
#  'accommodates bedrooms extra_people not_superhost': 1.6035914354342715,
#  'accommodates bedrooms extra_people number_of_amenities': -0.027074502274453023,
#  'accommodates bedrooms extra_people number_of_days_as_host': 0.0003762240851956407,
#  'accommodates bedrooms extra_people number_of_reviews': -0.001956652980005382,
#  'accommodates bedrooms extra_people rent_index': -0.002307964335118691,
#  'accommodates bedrooms extra_people review_period': -9.17776566916076e-05,
#  'accommodates bedrooms extra_people review_scores_cleanliness': -0.44937224611539706,
#  'accommodates bedrooms extra_people^2': 0.015546200652959334,
#  'accommodates bedrooms guests_included': -46.67267510177363,
#  'accommodates bedrooms guests_included extra_people': -0.09393862610418315,
#  'accommodates bedrooms guests_included is_superhost': -27.998683083626865,
#  'accommodates bedrooms guests_included not_superhost': -18.674403795981412,
#  'accommodates bedrooms guests_included number_of_amenities': 0.7772623557364631,
#  'accommodates bedrooms guests_included number_of_days_as_host': -0.015919342874352215,
#  'accommodates bedrooms guests_included number_of_reviews': -0.4522392809942467,
#  'accommodates bedrooms guests_included rent_index': 0.016270276424852754,
#  'accommodates bedrooms guests_included review_period': 0.0508775893256178,
#  'accommodates bedrooms guests_included review_scores_cleanliness': 6.100251170127237,
#  'accommodates bedrooms guests_included^2': -3.445017045046774,
#  'accommodates bedrooms is_superhost': 10.670794913920368,
#  'accommodates bedrooms is_superhost^2': 10.670527682533107,
#  'accommodates bedrooms not_superhost': -65.21070086523336,
#  'accommodates bedrooms not_superhost is_superhost': 6.4666162025855956e-09,
#  'accommodates bedrooms not_superhost^2': -65.21069232931875,
#  'accommodates bedrooms number_of_amenities': -6.963284144662655,
#  'accommodates bedrooms number_of_amenities is_superhost': -3.638747637911918,
#  'accommodates bedrooms number_of_amenities not_superhost': -3.3250338535092157,
#  'accommodates bedrooms number_of_amenities review_period': 0.005777403233389564,
#  'accommodates bedrooms number_of_amenities^2': 0.04589838240650524,
#  'accommodates bedrooms number_of_days_as_host': -0.11390339329660784,
#  'accommodates bedrooms number_of_days_as_host is_superhost': -0.05573437266881342,
#  'accommodates bedrooms number_of_days_as_host not_superhost': -0.05730764949500976,
#  'accommodates bedrooms number_of_days_as_host number_of_amenities': -0.0004138597193405104,
#  'accommodates bedrooms number_of_days_as_host review_period': -7.168656110668757e-05,
#  'accommodates bedrooms number_of_days_as_host^2': 1.3238518511213265e-06,
#  'accommodates bedrooms number_of_reviews': 3.8483408681252853,
#  'accommodates bedrooms number_of_reviews is_superhost': 1.750942387614288,
#  'accommodates bedrooms number_of_reviews not_superhost': 2.097472016605724,
#  'accommodates bedrooms number_of_reviews number_of_amenities': -0.0593660458727716,
#  'accommodates bedrooms number_of_reviews number_of_days_as_host': 0.0007633325183590389,
#  'accommodates bedrooms number_of_reviews rent_index': -0.0008098718577712746,
#  'accommodates bedrooms number_of_reviews review_period': -0.0010883821825309825,
#  'accommodates bedrooms number_of_reviews review_scores_cleanliness': 0.23507431895474606,
#  'accommodates bedrooms number_of_reviews^2': 0.0029880711797602025,
#  'accommodates bedrooms rent_index': 0.19346788555441222,
#  'accommodates bedrooms rent_index is_superhost': 0.09955959775108093,
#  'accommodates bedrooms rent_index not_superhost': 0.09478014213754166,
#  'accommodates bedrooms rent_index number_of_amenities': 0.002596364307116945,
#  'accommodates bedrooms rent_index number_of_days_as_host': 5.8290262712908054e-05,
#  'accommodates bedrooms rent_index review_period': 2.0084630976508336e-05,
#  'accommodates bedrooms rent_index^2': -7.668161659656799e-05,
#  'accommodates bedrooms review_period': 0.12851821286672607,
#  'accommodates bedrooms review_period is_superhost': 0.08096244072524049,
#  'accommodates bedrooms review_period not_superhost': 0.04679586365662653,
#  'accommodates bedrooms review_period^2': 4.76951836593423e-05,
#  'accommodates bedrooms review_scores_cleanliness': 14.506903119903217,
#  'accommodates bedrooms review_scores_cleanliness is_superhost': 20.022368441328908,
#  'accommodates bedrooms review_scores_cleanliness not_superhost': -5.516070446434579,
#  'accommodates bedrooms review_scores_cleanliness number_of_amenities': 0.34674142297119304,
#  'accommodates bedrooms review_scores_cleanliness number_of_days_as_host': 0.0024581814759892934,
#  'accommodates bedrooms review_scores_cleanliness rent_index': -0.007052520279156033,
#  'accommodates bedrooms review_scores_cleanliness review_period': -0.00994186938144519,
#  'accommodates bedrooms review_scores_cleanliness^2': 0.15192147059030708,
#  'accommodates bedrooms security_deposit': -0.30521633722307684,
#  'accommodates bedrooms security_deposit cleaning_fee': -0.002021639210846121,
#  'accommodates bedrooms security_deposit extra_people': 0.002144728309660514,
#  'accommodates bedrooms security_deposit guests_included': -0.0017469495344873897,
#  'accommodates bedrooms security_deposit is_superhost': -0.13959653765686314,
#  'accommodates bedrooms security_deposit not_superhost': -0.16519839727548857,
#  'accommodates bedrooms security_deposit number_of_amenities': -0.004747784765258268,
#  'accommodates bedrooms security_deposit number_of_days_as_host': 7.603440930531047e-05,
#  'accommodates bedrooms security_deposit number_of_reviews': -0.0029709952961452625,
#  'accommodates bedrooms security_deposit rent_index': 4.404356275734728e-06,
#  'accommodates bedrooms security_deposit review_period': 0.000130683321414432,
#  'accommodates bedrooms security_deposit review_scores_cleanliness': 0.020441072029484583,
#  'accommodates bedrooms security_deposit^2': -5.18638537954145e-05,
#  'accommodates bedrooms^2': 56.10530468366607,
#  'accommodates bedrooms^2 beds': 16.248793889914293,
#  'accommodates bedrooms^2 cleaning_fee': 0.41941985779991714,
#  'accommodates bedrooms^2 extra_people': 0.272481841161856,
#  'accommodates bedrooms^2 guests_included': -5.199581892232827,
#  'accommodates bedrooms^2 is_superhost': 23.247850795158843,
#  'accommodates bedrooms^2 not_superhost': 32.85727403820645,
#  'accommodates bedrooms^2 number_of_amenities': -1.6144397013040512,
#  'accommodates bedrooms^2 number_of_days_as_host': 0.012081407271712996,
#  'accommodates bedrooms^2 number_of_reviews': 0.061519289206792276,
#  'accommodates bedrooms^2 rent_index': -0.02897084791261797,
#  'accommodates bedrooms^2 review_period': -0.002324154110780645,
#  'accommodates bedrooms^2 review_scores_cleanliness': 1.1740467956629677,
#  'accommodates bedrooms^2 security_deposit': -0.03751615510718988,
#  'accommodates bedrooms^3': -11.473378271940119,
#  'accommodates beds': -48.44027715734995,
#  'accommodates beds cleaning_fee': 0.9556488562459182,
#  'accommodates beds cleaning_fee extra_people': 0.02361231975026238,
#  'accommodates beds cleaning_fee guests_included': -0.1488454021755308,
#  'accommodates beds cleaning_fee is_superhost': 0.29971953604649626,
#  'accommodates beds cleaning_fee not_superhost': 0.6557332674317761,
#  'accommodates beds cleaning_fee number_of_amenities': -0.02497849307679686,
#  'accommodates beds cleaning_fee number_of_days_as_host': 0.00023657669255534717,
#  'accommodates beds cleaning_fee number_of_reviews': -0.00851622794176336,
#  'accommodates beds cleaning_fee rent_index': -0.00023016004266772908,
#  'accommodates beds cleaning_fee review_period': 0.0008602532486142506,
#  'accommodates beds cleaning_fee review_scores_cleanliness': -0.0844024123345273,
#  'accommodates beds cleaning_fee^2': -0.007515802419000685,
#  'accommodates beds extra_people': -3.2330682704794143,
#  'accommodates beds extra_people is_superhost': -1.3664700516803325,
#  'accommodates beds extra_people not_superhost': -1.867061835672021,
#  'accommodates beds extra_people number_of_amenities': -0.03922329581004426,
#  'accommodates beds extra_people number_of_days_as_host': 0.000247722504213786,
#  'accommodates beds extra_people number_of_reviews': 0.014101001313318757,
#  'accommodates beds extra_people rent_index': 0.001416704931033741,
#  'accommodates beds extra_people review_period': -0.0004438878044577022,
#  'accommodates beds extra_people review_scores_cleanliness': 0.04289136086557795,
#  'accommodates beds extra_people^2': 0.0009491155486223937,
#  'accommodates beds guests_included': 62.9495978161575,
#  'accommodates beds guests_included extra_people': -0.28133238078563055,
#  'accommodates beds guests_included is_superhost': 30.198944587725748,
#  'accommodates beds guests_included not_superhost': 32.751433581533526,
#  'accommodates beds guests_included number_of_amenities': 0.3344132607841079,
#  'accommodates beds guests_included number_of_days_as_host': -0.0042836482732507095,
#  'accommodates beds guests_included number_of_reviews': 0.1385490879595081,
#  'accommodates beds guests_included rent_index': -0.0065483154081154675,
#  'accommodates beds guests_included review_period': -0.019509107976255873,
#  'accommodates beds guests_included review_scores_cleanliness': -1.6839692138763602,
#  'accommodates beds guests_included^2': 2.3185844431071367,
#  'accommodates beds is_superhost': -87.35726757476323,
#  'accommodates beds is_superhost^2': -87.35739488838313,
#  'accommodates beds not_superhost': 38.225151275213676,
#  'accommodates beds not_superhost is_superhost': 2.259348362045055e-08,
#  'accommodates beds not_superhost^2': 38.2261846786694,
#  'accommodates beds number_of_amenities': 3.6006426270573315,
#  'accommodates beds number_of_amenities is_superhost': 1.4206917497798088,
#  'accommodates beds number_of_amenities not_superhost': 2.180108604540617,
#  'accommodates beds number_of_amenities review_period': -0.0016684472037248304,
#  'accommodates beds number_of_amenities^2': -0.018826066050727557,
#  'accommodates beds number_of_days_as_host': -0.03546985254369147,
#  'accommodates beds number_of_days_as_host is_superhost': -0.010716878321109811,
#  'accommodates beds number_of_days_as_host not_superhost': -0.024739824952250102,
#  'accommodates beds number_of_days_as_host number_of_amenities': -0.0003835512183282744,
#  'accommodates beds number_of_days_as_host review_period': 1.6148955268681664e-05,
#  'accommodates beds number_of_days_as_host^2': 2.4143069367706175e-06,
#  'accommodates beds number_of_reviews': -5.642656989606456,
#  'accommodates beds number_of_reviews is_superhost': -2.820780066978603,
#  'accommodates beds number_of_reviews not_superhost': -2.8214059213033003,
#  'accommodates beds number_of_reviews number_of_amenities': 0.007039611762912683,
#  'accommodates beds number_of_reviews number_of_days_as_host': -0.0005771270720759574,
#  'accommodates beds number_of_reviews rent_index': 0.0013896398349065283,
#  'accommodates beds number_of_reviews review_period': 0.0015499955382514779,
#  'accommodates beds number_of_reviews review_scores_cleanliness': 0.2951959651970617,
#  'accommodates beds number_of_reviews^2': -0.005487655717262256,
#  'accommodates beds rent_index': -0.09082523524434287,
#  'accommodates beds rent_index is_superhost': -0.057784061298132364,
#  'accommodates beds rent_index not_superhost': -0.032770440748103966,
#  'accommodates beds rent_index number_of_amenities': -0.0017303581797887097,
#  'accommodates beds rent_index number_of_days_as_host': 2.291635746583583e-05,
#  'accommodates beds rent_index review_period': -7.594471814482554e-05,
#  'accommodates beds rent_index^2': 4.063953133255288e-05,
#  'accommodates beds review_period': 0.26873553831849206,
#  'accommodates beds review_period is_superhost': 0.13075109799213816,
#  'accommodates beds review_period not_superhost': 0.13770060044933727,
#  'accommodates beds review_period^2': -7.003124740199426e-05,
#  'accommodates beds review_scores_cleanliness': 5.710339610573415,
#  'accommodates beds review_scores_cleanliness is_superhost': -1.6201815263485653,
#  'accommodates beds review_scores_cleanliness not_superhost': 7.330702760584194,
#  'accommodates beds review_scores_cleanliness number_of_amenities': -0.2643636596316215,
#  'accommodates beds review_scores_cleanliness number_of_days_as_host': -0.001311565680667557,
#  'accommodates beds review_scores_cleanliness rent_index': -0.0009953657692374105,
#  'accommodates beds review_scores_cleanliness review_period': -0.019524858498759474,
#  'accommodates beds review_scores_cleanliness^2': 0.013365201283193195,
#  'accommodates beds security_deposit': -0.3588199429103385,
#  'accommodates beds security_deposit cleaning_fee': 0.003286691544061503,
#  'accommodates beds security_deposit extra_people': -0.003179741455446763,
#  'accommodates beds security_deposit guests_included': 0.010903347353070802,
#  'accommodates beds security_deposit is_superhost': -0.16272585998201256,
#  'accommodates beds security_deposit not_superhost': -0.19637967515644003,
#  'accommodates beds security_deposit number_of_amenities': 0.01023938886613494,
#  'accommodates beds security_deposit number_of_days_as_host': -2.5999535230402777e-05,
#  'accommodates beds security_deposit number_of_reviews': -0.0004361468917650387,
#  'accommodates beds security_deposit rent_index': 1.2728758533987686e-05,
#  'accommodates beds security_deposit review_period': -6.417010650698874e-06,
#  'accommodates beds security_deposit review_scores_cleanliness': 0.008447174174343238,
#  'accommodates beds security_deposit^2': -0.00014113320350120313,
#  'accommodates beds^2': 9.196595950631789,
#  'accommodates beds^2 cleaning_fee': 0.0499139130267419,
#  'accommodates beds^2 extra_people': -0.06461386462215407,
#  'accommodates beds^2 guests_included': -2.84950604934953,
#  'accommodates beds^2 is_superhost': -1.6224772715994702,
#  'accommodates beds^2 not_superhost': 10.819171242600426,
#  'accommodates beds^2 number_of_amenities': -0.7469006576209959,
#  'accommodates beds^2 number_of_days_as_host': -0.005771083397157603,
#  'accommodates beds^2 number_of_reviews': 0.18983449301911934,
#  'accommodates beds^2 rent_index': 0.006750679852178245,
#  'accommodates beds^2 review_period': 0.016661512573339445,
#  'accommodates beds^2 review_scores_cleanliness': -1.4868608598115174,
#  'accommodates beds^2 security_deposit': -0.002148863477824655,
#  'accommodates beds^3': -0.7407716004308371,
#  'accommodates cleaning_fee': 2.9284017963041094,
#  'accommodates cleaning_fee extra_people': -0.06824355236932403,
#  'accommodates cleaning_fee extra_people is_superhost': -0.02749772226745162,
#  'accommodates cleaning_fee extra_people not_superhost': -0.04103883355009834,
#  'accommodates cleaning_fee extra_people number_of_amenities': 0.00012587868920603255,
#  'accommodates cleaning_fee extra_people number_of_days_as_host': 1.2905855178959208e-05,
#  'accommodates cleaning_fee extra_people number_of_reviews': -7.085926444593923e-05,
#  'accommodates cleaning_fee extra_people rent_index': 1.176665432440848e-05,
#  'accommodates cleaning_fee extra_people review_period': -2.0816673823216478e-05,
#  'accommodates cleaning_fee extra_people review_scores_cleanliness': -0.0012167251682843516,
#  'accommodates cleaning_fee extra_people^2': 0.00014901455608246544,
#  'accommodates cleaning_fee guests_included': 0.9600042922095995,
#  'accommodates cleaning_fee guests_included extra_people': -0.0015499012369195513,
#  'accommodates cleaning_fee guests_included is_superhost': 0.5662304078208329,
#  'accommodates cleaning_fee guests_included not_superhost': 0.394147287255537,
#  'accommodates cleaning_fee guests_included number_of_amenities': 0.003539778788016776,
#  'accommodates cleaning_fee guests_included number_of_days_as_host': -0.00011778179239339842,
#  'accommodates cleaning_fee guests_included number_of_reviews': 0.0005024585424870894,
#  'accommodates cleaning_fee guests_included rent_index': -0.0005573311692197174,
#  'accommodates cleaning_fee guests_included review_period': 0.0002382312180433955,
#  'accommodates cleaning_fee guests_included review_scores_cleanliness': -0.05374493123095995,
#  'accommodates cleaning_fee guests_included^2': 0.009251770203387853,
#  'accommodates cleaning_fee is_superhost': 2.248364017704053,
#  'accommodates cleaning_fee is_superhost^2': 2.248753873752883,
#  'accommodates cleaning_fee not_superhost': 1.3671096082785454,
#  'accommodates cleaning_fee not_superhost is_superhost': 4.581718968631188e-09,
#  'accommodates cleaning_fee not_superhost^2': 1.3674048643062777,
#  'accommodates cleaning_fee number_of_amenities': -0.07563773821563251,
#  'accommodates cleaning_fee number_of_amenities is_superhost': -0.05734699190894829,
#  'accommodates cleaning_fee number_of_amenities not_superhost': -0.01794691398356912,
#  'accommodates cleaning_fee number_of_amenities review_period': -1.5633293872524704e-05,
#  'accommodates cleaning_fee number_of_amenities^2': 0.001184213246035369,
#  'accommodates cleaning_fee number_of_days_as_host': -0.001617891662604964,
#  'accommodates cleaning_fee number_of_days_as_host is_superhost': -0.0010378192840690837,
#  'accommodates cleaning_fee number_of_days_as_host not_superhost': -0.0005170364518638804,
#  'accommodates cleaning_fee number_of_days_as_host number_of_amenities': 6.201326566143442e-07,
#  'accommodates cleaning_fee number_of_days_as_host review_period': 3.8248752099248606e-07,
#  'accommodates cleaning_fee number_of_days_as_host^2': -1.2211705065685613e-07,
#  'accommodates cleaning_fee number_of_reviews': 0.12252682823190464,
#  'accommodates cleaning_fee number_of_reviews is_superhost': 0.06542079935216895,
#  'accommodates cleaning_fee number_of_reviews not_superhost': 0.056472951248089,
#  'accommodates cleaning_fee number_of_reviews number_of_amenities': 0.00016364355074690074,
#  'accommodates cleaning_fee number_of_reviews number_of_days_as_host': 3.846858770191196e-06,
#  'accommodates cleaning_fee number_of_reviews rent_index': 5.57273355920947e-06,
#  'accommodates cleaning_fee number_of_reviews review_period': -1.874435708019991e-05,
#  'accommodates cleaning_fee number_of_reviews review_scores_cleanliness': -0.012189744412370827,
#  'accommodates cleaning_fee number_of_reviews^2': 2.7250673837326044e-07,
#  'accommodates cleaning_fee rent_index': -0.0016173792683994261,
#  'accommodates cleaning_fee rent_index is_superhost': -0.0007072465523209128,
#  'accommodates cleaning_fee rent_index not_superhost': -0.00043345000974294424,
#  'accommodates cleaning_fee rent_index number_of_amenities': 6.952867929130619e-05,
#  'accommodates cleaning_fee rent_index number_of_days_as_host': 1.7420588519566718e-06,
#  'accommodates cleaning_fee rent_index review_period': -1.4027500348859356e-06,
#  'accommodates cleaning_fee rent_index^2': -1.5192269276399382e-06,
#  'accommodates cleaning_fee review_period': -0.004081487937035019,
#  'accommodates cleaning_fee review_period is_superhost': -0.0018729864125054845,
#  'accommodates cleaning_fee review_period not_superhost': -0.0019612924764497554,
#  'accommodates cleaning_fee review_period^2': 1.0621506854988257e-06,
#  'accommodates cleaning_fee review_scores_cleanliness': 0.14635330368886354,
#  'accommodates cleaning_fee review_scores_cleanliness is_superhost': 0.18179283904444507,
#  'accommodates cleaning_fee review_scores_cleanliness not_superhost': -0.03587553024924546,
#  'accommodates cleaning_fee review_scores_cleanliness number_of_amenities': 0.0019529645822615866,
#  'accommodates cleaning_fee review_scores_cleanliness number_of_days_as_host': -2.3607316256774295e-05,
#  'accommodates cleaning_fee review_scores_cleanliness rent_index': 9.758414230284063e-05,
#  'accommodates cleaning_fee review_scores_cleanliness review_period': 0.0007679091629178586,
#  'accommodates cleaning_fee review_scores_cleanliness^2': -0.019279239796085826,
#  'accommodates cleaning_fee^2': -0.0071079775117712084,
#  'accommodates cleaning_fee^2 extra_people': 6.332793708944524e-05,
#  'accommodates cleaning_fee^2 guests_included': -0.0015894259501318194,
#  'accommodates cleaning_fee^2 is_superhost': -0.0041501908445286985,
#  'accommodates cleaning_fee^2 not_superhost': -0.0027932997815403914,
#  'accommodates cleaning_fee^2 number_of_amenities': -0.00041794457402262523,
#  'accommodates cleaning_fee^2 number_of_days_as_host': -3.7096574259245867e-06,
#  'accommodates cleaning_fee^2 number_of_reviews': 8.641607977354597e-05,
#  'accommodates cleaning_fee^2 rent_index': 1.53814506000201e-05,
#  'accommodates cleaning_fee^2 review_period': 4.364280678723848e-06,
#  'accommodates cleaning_fee^2 review_scores_cleanliness': -0.0010023965791028653,
#  'accommodates cleaning_fee^3': -8.73785497101793e-06,
#  'accommodates extra_people': 9.391642293873588,
#  'accommodates extra_people is_superhost': 2.5072876721950297,
#  'accommodates extra_people is_superhost^2': 2.5074547714199533,
#  'accommodates extra_people not_superhost': 6.327495990924986,
#  'accommodates extra_people not_superhost is_superhost': -7.258436081347686e-09,
#  'accommodates extra_people not_superhost^2': 6.327261524056582,
#  'accommodates extra_people number_of_amenities': 0.2025017812890858,
#  'accommodates extra_people number_of_amenities is_superhost': 0.13163178566045894,
#  'accommodates extra_people number_of_amenities not_superhost': 0.0710820904127162,
#  'accommodates extra_people number_of_amenities review_period': 7.712203357932928e-05,
#  'accommodates extra_people number_of_amenities^2': -0.0004774279130794683,
#  'accommodates extra_people number_of_days_as_host': 0.0012372173767896694,
#  'accommodates extra_people number_of_days_as_host is_superhost': -0.00032391209946985925,
#  'accommodates extra_people number_of_days_as_host not_superhost': 0.0014585171497087958,
#  'accommodates extra_people number_of_days_as_host number_of_amenities': -1.8288408826458464e-05,
#  'accommodates extra_people number_of_days_as_host review_period': 5.3766584396449e-07,
#  'accommodates extra_people number_of_days_as_host^2': 3.589061674036994e-07,
#  'accommodates extra_people number_of_reviews': 0.06100603752264257,
#  'accommodates extra_people number_of_reviews is_superhost': 0.03920025377986593,
#  'accommodates extra_people number_of_reviews not_superhost': 0.022129787684631138,
#  'accommodates extra_people number_of_reviews number_of_amenities': -0.0010436993415829604,
#  'accommodates extra_people number_of_reviews number_of_days_as_host': -3.0084829261338927e-05,
#  'accommodates extra_people number_of_reviews rent_index': 1.6079673627101985e-05,
#  'accommodates extra_people number_of_reviews review_period': 3.2112868697066836e-05,
#  'accommodates extra_people number_of_reviews review_scores_cleanliness': 0.0037412269556728987,
#  'accommodates extra_people number_of_reviews^2': -0.00010727688698146479,
#  'accommodates extra_people rent_index': -0.014926332671889982,
#  'accommodates extra_people rent_index is_superhost': -0.0074736610185688265,
#  'accommodates extra_people rent_index not_superhost': -0.00764771773326836,
#  'accommodates extra_people rent_index number_of_amenities': -9.131971228168123e-05,
#  'accommodates extra_people rent_index number_of_days_as_host': -2.3536411005031658e-06,
#  'accommodates extra_people rent_index review_period': -4.0922480286419236e-08,
#  'accommodates extra_people rent_index^2': 5.443525327993341e-06,
#  'accommodates extra_people review_period': -0.00351773678237459,
#  'accommodates extra_people review_period is_superhost': -0.0016086080876754334,
#  'accommodates extra_people review_period not_superhost': -0.0020301195333601836,
#  'accommodates extra_people review_period^2': -9.698773476454585e-07,
#  'accommodates extra_people review_scores_cleanliness': -0.16242634278718485,
#  'accommodates extra_people review_scores_cleanliness is_superhost': -0.21528207396103713,
#  'accommodates extra_people review_scores_cleanliness not_superhost': 0.05306388608384057,
#  'accommodates extra_people review_scores_cleanliness number_of_amenities': -0.01032195724387033,
#  'accommodates extra_people review_scores_cleanliness number_of_days_as_host': 0.0002753432867270355,
#  'accommodates extra_people review_scores_cleanliness rent_index': -0.00016217125715611546,
#  'accommodates extra_people review_scores_cleanliness review_period': 0.0003991259309549433,
#  'accommodates extra_people review_scores_cleanliness^2': 0.01659213040109829,
#  'accommodates extra_people^2': 0.12051526732904831,
#  'accommodates extra_people^2 is_superhost': 0.05096534184237757,
#  'accommodates extra_people^2 not_superhost': 0.06970691491045707,
#  'accommodates extra_people^2 number_of_amenities': 4.566125235233719e-05,
#  'accommodates extra_people^2 number_of_days_as_host': 9.939729741271616e-06,
#  'accommodates extra_people^2 number_of_reviews': 0.000220911175647384,
#  'accommodates extra_people^2 rent_index': -7.318510249404426e-05,
#  'accommodates extra_people^2 review_period': 9.368390432322e-07,
#  'accommodates extra_people^2 review_scores_cleanliness': 0.004982874513537406,
#  'accommodates extra_people^3': -4.62900510084982e-05,
#  'accommodates guests_included': -10.05705258459809,
#  'accommodates guests_included extra_people': -1.0432163595747632,
#  'accommodates guests_included extra_people is_superhost': -0.3794012213435378,
#  'accommodates guests_included extra_people not_superhost': -0.6634477446164165,
#  'accommodates guests_included extra_people number_of_amenities': -0.032752628402426175,
#  'accommodates guests_included extra_people number_of_days_as_host': -0.00022923846809263807,
#  'accommodates guests_included extra_people number_of_reviews': -0.009071295738966754,
#  'accommodates guests_included extra_people rent_index': 0.0004506855256085801,
#  'accommodates guests_included extra_people review_period': 1.268789695716503e-05,
#  'accommodates guests_included extra_people review_scores_cleanliness': 0.08133752221034277,
#  'accommodates guests_included extra_people^2': -0.0029814358368425156,
#  'accommodates guests_included is_superhost': -0.830844499573454,
#  'accommodates guests_included is_superhost^2': -0.8308608390689821,
#  'accommodates guests_included not_superhost': -9.11308030758379,
#  'accommodates guests_included not_superhost is_superhost': -4.461990237361602e-09,
#  'accommodates guests_included not_superhost^2': -9.113188493220102,
#  'accommodates guests_included number_of_amenities': -3.2818331207158415,
#  'accommodates guests_included number_of_amenities is_superhost': -2.186686783009195,
#  'accommodates guests_included number_of_amenities not_superhost': -1.0945401588811503,
#  'accommodates guests_included number_of_amenities review_period': 0.00045022355357113075,
#  'accommodates guests_included number_of_amenities^2': -0.016034926083991284,
#  'accommodates guests_included number_of_days_as_host': -0.047952416841678266,
#  'accommodates guests_included number_of_days_as_host is_superhost': -0.013496868477080112,
#  'accommodates guests_included number_of_days_as_host not_superhost': -0.03454161488725175,
#  'accommodates guests_included number_of_days_as_host number_of_amenities': -0.00025871865365493716,
#  'accommodates guests_included number_of_days_as_host review_period': 3.0383755740617768e-06,
#  'accommodates guests_included number_of_days_as_host^2': -1.3067932281516785e-06,
#  'accommodates guests_included number_of_reviews': 1.5396487416683446,
#  'accommodates guests_included number_of_reviews is_superhost': 0.8864769337558663,
#  'accommodates guests_included number_of_reviews not_superhost': 0.6534095645595461,
#  'accommodates guests_included number_of_reviews number_of_amenities': 0.0005459885124263681,
#  'accommodates guests_included number_of_reviews number_of_days_as_host': 0.00017414699723373236,
#  'accommodates guests_included number_of_reviews rent_index': -0.00010777015711037803,
#  'accommodates guests_included number_of_reviews review_period': -0.0009669683288365591,
#  'accommodates guests_included number_of_reviews review_scores_cleanliness': -0.026963942204710007,
#  'accommodates guests_included number_of_reviews^2': 0.004477118032106691,
#  'accommodates guests_included rent_index': -0.00741811407022817,
#  'accommodates guests_included rent_index is_superhost': -0.008694318102750011,
#  'accommodates guests_included rent_index not_superhost': 0.0010561688797758786,
#  'accommodates guests_included rent_index number_of_amenities': 0.0020938376529821747,
#  'accommodates guests_included rent_index number_of_days_as_host': 1.2683208667374897e-05,
#  'accommodates guests_included rent_index review_period': 1.678416276574902e-05,
#  'accommodates guests_included rent_index^2': 3.580060545741939e-05,
#  'accommodates guests_included review_period': 0.03432740728189942,
#  'accommodates guests_included review_period is_superhost': 0.016111157382250465,
#  'accommodates guests_included review_period not_superhost': 0.01850810209755196,
#  'accommodates guests_included review_period^2': 6.247514464775993e-06,
#  'accommodates guests_included review_scores_cleanliness': -12.672464009529438,
#  'accommodates guests_included review_scores_cleanliness is_superhost': -10.146187274573723,
#  'accommodates guests_included review_scores_cleanliness not_superhost': -2.5261120529103938,
#  'accommodates guests_included review_scores_cleanliness number_of_amenities': 0.11631469062228603,
#  'accommodates guests_included review_scores_cleanliness number_of_days_as_host': 0.00344157601411547,
#  'accommodates guests_included review_scores_cleanliness rent_index': -0.0017366642039479585,
#  'accommodates guests_included review_scores_cleanliness review_period': -0.014316693607733352,
#  'accommodates guests_included review_scores_cleanliness^2': 0.7696103237495129,
#  'accommodates guests_included^2': 0.3445935268601961,
#  'accommodates guests_included^2 extra_people': -0.032126447747207916,
#  'accommodates guests_included^2 is_superhost': -2.276358492486248,
#  'accommodates guests_included^2 not_superhost': 2.6207486463184337,
#  'accommodates guests_included^2 number_of_amenities': 0.17689086806969306,
#  'accommodates guests_included^2 number_of_days_as_host': -0.0020050774801033274,
#  'accommodates guests_included^2 number_of_reviews': 0.06472441350409974,
#  'accommodates guests_included^2 rent_index': -0.005317984198057619,
#  'accommodates guests_included^2 review_period': 0.005250684686436566,
#  'accommodates guests_included^2 review_scores_cleanliness': 0.1099658142338301,
#  'accommodates guests_included^3': 2.568947131238879,
#  'accommodates is_superhost': -2.20198417251447,
#  'accommodates is_superhost^2': -2.456792176395283,
#  'accommodates is_superhost^3': -2.4566870100485394,
#  'accommodates not_superhost': -3.5328637963372302,
#  'accommodates not_superhost is_superhost': -0.00023100133484805108,
#  'accommodates not_superhost is_superhost^2': -3.247230815836555e-09,
#  'accommodates not_superhost^2': -3.4226243773616916,
#  'accommodates not_superhost^2 is_superhost': 8.552851482601653e-11,
#  'accommodates not_superhost^3': -3.4227333237819138,
#  'accommodates number_of_amenities': -25.22904894046938,
#  'accommodates number_of_amenities is_superhost': -12.97779561998952,
#  'accommodates number_of_amenities is_superhost^2': -12.978065428365781,
#  'accommodates number_of_amenities not_superhost': -12.068122123311595,
#  'accommodates number_of_amenities not_superhost is_superhost': 2.1541504326844096e-09,
#  'accommodates number_of_amenities not_superhost^2': -12.0682802792185,
#  'accommodates number_of_amenities review_period': -0.0016737447522929452,
#  'accommodates number_of_amenities review_period is_superhost': 8.501239809878604e-05,
#  'accommodates number_of_amenities review_period not_superhost': -0.0017364119233836603,
#  'accommodates number_of_amenities review_period^2': 4.0148274289597324e-06,
#  'accommodates number_of_amenities^2': 0.011711002945742913,
#  'accommodates number_of_amenities^2 is_superhost': 0.01182034502017992,
#  'accommodates number_of_amenities^2 not_superhost': 7.95283351475877e-05,
#  'accommodates number_of_amenities^2 review_period': -0.00012247191950543577,
#  'accommodates number_of_amenities^3': -0.00016313622834053255,
#  'accommodates number_of_days_as_host': 0.053334125889080486,
#  'accommodates number_of_days_as_host is_superhost': -0.07689617736364676,
#  'accommodates number_of_days_as_host is_superhost^2': -0.07707804128426833,
#  'accommodates number_of_days_as_host not_superhost': 0.02690247240240524,
#  'accommodates number_of_days_as_host not_superhost is_superhost': 2.559234725616616e-09,
#  'accommodates number_of_days_as_host not_superhost^2': 0.026772686294821192,
#  'accommodates number_of_days_as_host number_of_amenities': -2.0262207457467854e-05,
#  'accommodates number_of_days_as_host number_of_amenities is_superhost': 0.0006768013581663396,
#  'accommodates number_of_days_as_host number_of_amenities not_superhost': -0.000580846494897443,
#  'accommodates number_of_days_as_host number_of_amenities review_period': -2.829326982801278e-06,
#  'accommodates number_of_days_as_host number_of_amenities^2': -1.4846319564576952e-05,
#  'accommodates number_of_days_as_host review_period': 6.268611068643065e-05,
#  'accommodates number_of_days_as_host review_period is_superhost': 0.0001013690133316167,
#  'accommodates number_of_days_as_host review_period not_superhost': 4.814706346550206e-05,
#  'accommodates number_of_days_as_host review_period^2': 3.8809183307980666e-08,
#  'accommodates number_of_days_as_host^2': -2.152804581959325e-05,
#  'accommodates number_of_days_as_host^2 is_superhost': -5.288501042706666e-05,
#  'accommodates number_of_days_as_host^2 not_superhost': -4.368024320528189e-05,
#  'accommodates number_of_days_as_host^2 number_of_amenities': 1.96920837978792e-06,
#  'accommodates number_of_days_as_host^2 review_period': -9.969058120673502e-09,
#  'accommodates number_of_days_as_host^3': 2.234016541202699e-09,
#  'accommodates number_of_reviews': 10.834546807151007,
#  'accommodates number_of_reviews is_superhost': 5.530839779991968,
#  'accommodates number_of_reviews is_superhost^2': 5.5310733156738126,
#  'accommodates number_of_reviews not_superhost': 5.97593916273562,
#  'accommodates number_of_reviews not_superhost is_superhost': 1.6061356862551168e-09,
#  'accommodates number_of_reviews not_superhost^2': 5.975688057729119,
#  'accommodates number_of_reviews number_of_amenities': 0.08326864336128763,
#  'accommodates number_of_reviews number_of_amenities is_superhost': 0.03621369861313929,
#  'accommodates number_of_reviews number_of_amenities not_superhost': 0.047334513091537425,
#  'accommodates number_of_reviews number_of_amenities review_period': -2.5628199341840167e-05,
#  'accommodates number_of_reviews number_of_amenities^2': 0.0008030064700159453,
#  'accommodates number_of_reviews number_of_days_as_host': 0.0023379723615867933,
#  'accommodates number_of_reviews number_of_days_as_host is_superhost': 0.0010351126379866075,
#  'accommodates number_of_reviews number_of_days_as_host not_superhost': 0.001079221436952559,
#  'accommodates number_of_reviews number_of_days_as_host number_of_amenities': 1.3612389767286783e-05,
#  'accommodates number_of_reviews number_of_days_as_host review_period': -5.204369149507809e-07,
#  'accommodates number_of_reviews number_of_days_as_host^2': -3.164921922151412e-07,
#  'accommodates number_of_reviews rent_index': 0.002578392254480314,
#  'accommodates number_of_reviews rent_index is_superhost': 0.001255715003494751,
#  'accommodates number_of_reviews rent_index not_superhost': 0.0011113424619554665,
#  'accommodates number_of_reviews rent_index number_of_amenities': -1.3654728168960935e-05,
#  'accommodates number_of_reviews rent_index number_of_days_as_host': 5.679905281169226e-07,
#  'accommodates number_of_reviews rent_index review_period': 1.8539998192560435e-07,
#  'accommodates number_of_reviews rent_index^2': -2.4823463173123325e-06,
#  'accommodates number_of_reviews review_period': 0.0010868393905591757,
#  'accommodates number_of_reviews review_period is_superhost': 0.001355626657250184,
#  'accommodates number_of_reviews review_period not_superhost': -0.00011229807193566125,
#  'accommodates number_of_reviews review_period^2': 1.1901824960116637e-06,
#  'accommodates number_of_reviews review_scores_cleanliness': -2.249137363022843,
# ...
#  'security_deposit number_of_reviews number_of_amenities review_period': -8.033602995794094e-08,
#  'security_deposit number_of_reviews number_of_amenities^2': -9.846481131366764e-06,
#  'security_deposit number_of_reviews number_of_days_as_host': 3.8023622295777495e-05,
#  'security_deposit number_of_reviews number_of_days_as_host is_superhost': -3.0960415610574413e-05,
#  'security_deposit number_of_reviews number_of_days_as_host not_superhost': -3.346390362095617e-05,
#  'security_deposit number_of_reviews number_of_days_as_host number_of_amenities': 2.6305968311806077e-08,
#  'security_deposit number_of_reviews number_of_days_as_host review_period': 1.374919893215587e-09,
#  'security_deposit number_of_reviews number_of_days_as_host^2': 1.3105099175986235e-09,
#  'security_deposit number_of_reviews rent_index': 0.00014409821118848803,
#  'security_deposit number_of_reviews rent_index is_superhost': -0.00014526876318722015,
#  'security_deposit number_of_reviews rent_index not_superhost': -0.00014111596857814313,
#  'security_deposit number_of_reviews rent_index number_of_amenities': -3.3445050244421473e-07,
#  'security_deposit number_of_reviews rent_index number_of_days_as_host': -3.736594991754494e-10,
#  'security_deposit number_of_reviews rent_index review_period': 4.147816971833418e-09,
#  'security_deposit number_of_reviews rent_index^2': 3.482282850963969e-09,
#  'security_deposit number_of_reviews review_period': 9.542437107788825e-05,
#  'security_deposit number_of_reviews review_period is_superhost': -2.8829889794943585e-05,
#  'security_deposit number_of_reviews review_period not_superhost': -2.6541837361767608e-05,
#  'security_deposit number_of_reviews review_period^2': -4.437800613099618e-09,
#  'security_deposit number_of_reviews review_scores_cleanliness': 0.0177398205094332,
#  'security_deposit number_of_reviews review_scores_cleanliness is_superhost': 0.007383895458001115,
#  'security_deposit number_of_reviews review_scores_cleanliness not_superhost': 0.010364987792997282,
#  'security_deposit number_of_reviews review_scores_cleanliness number_of_amenities': -0.0001717599621938006,
#  'security_deposit number_of_reviews review_scores_cleanliness number_of_days_as_host': -2.0156118079714316e-06,
#  'security_deposit number_of_reviews review_scores_cleanliness rent_index': 4.880088851742987e-06,
#  'security_deposit number_of_reviews review_scores_cleanliness review_period': -1.6061614135429842e-06,
#  'security_deposit number_of_reviews review_scores_cleanliness^2': -0.0014814426566072169,
#  'security_deposit number_of_reviews^2': 7.34602430209018e-05,
#  'security_deposit number_of_reviews^2 is_superhost': 2.0929510636209568e-05,
#  'security_deposit number_of_reviews^2 not_superhost': 3.618566433656318e-05,
#  'security_deposit number_of_reviews^2 number_of_amenities': -6.821008848579538e-07,
#  'security_deposit number_of_reviews^2 number_of_days_as_host': -1.500693650033011e-08,
#  'security_deposit number_of_reviews^2 rent_index': -4.6598416071977344e-08,
#  'security_deposit number_of_reviews^2 review_period': 7.742303196516323e-08,
#  'security_deposit number_of_reviews^2 review_scores_cleanliness': 2.4051048864993253e-06,
#  'security_deposit number_of_reviews^3': -2.476179584706489e-07,
#  'security_deposit rent_index': 0.0236988215930711,
#  'security_deposit rent_index is_superhost': 0.0022706143995877724,
#  'security_deposit rent_index is_superhost^2': 0.002272641323036835,
#  'security_deposit rent_index not_superhost': -0.002387082734376285,
#  'security_deposit rent_index not_superhost is_superhost': 0.0,
#  'security_deposit rent_index not_superhost^2': -0.002391719258831197,
#  'security_deposit rent_index number_of_amenities': -0.00013373462796931112,
#  'security_deposit rent_index number_of_amenities is_superhost': -7.606068089462454e-05,
#  'security_deposit rent_index number_of_amenities not_superhost': -8.899936547653251e-05,
#  'security_deposit rent_index number_of_amenities review_period': -6.53197886057999e-09,
#  'security_deposit rent_index number_of_amenities^2': 2.0521476258068697e-07,
#  'security_deposit rent_index number_of_days_as_host': 0.0017573331859332365,
#  'security_deposit rent_index number_of_days_as_host is_superhost': -0.0017583619662961286,
#  'security_deposit rent_index number_of_days_as_host not_superhost': -0.0017582416583581428,
#  'security_deposit rent_index number_of_days_as_host number_of_amenities': -1.2709602467686487e-08,
#  'security_deposit rent_index number_of_days_as_host review_period': -3.931244219046448e-10,
#  'security_deposit rent_index number_of_days_as_host^2': -2.585340830307814e-10,
#  'security_deposit rent_index review_period': 0.00023583033625636577,
#  'security_deposit rent_index review_period is_superhost': -0.0002354600365620012,
#  'security_deposit rent_index review_period not_superhost': -0.00023576679938050297,
#  'security_deposit rent_index review_period^2': 3.0726132749236967e-10,
#  'security_deposit rent_index^2': 0.002221179442574062,
#  'security_deposit rent_index^2 is_superhost': -0.0022258415948376983,
#  'security_deposit rent_index^2 not_superhost': -0.0022248041690993256,
#  'security_deposit rent_index^2 number_of_amenities': 4.4624824724337486e-08,
#  'security_deposit rent_index^2 number_of_days_as_host': 3.6129055303035784e-10,
#  'security_deposit rent_index^2 review_period': -4.662241703812242e-10,
#  'security_deposit rent_index^3': 5.736922048527049e-11,
#  'security_deposit review_period': -0.013055449467958868,
#  'security_deposit review_period is_superhost': 0.0009547419681014134,
#  'security_deposit review_period is_superhost^2': 0.0009498620596748996,
#  'security_deposit review_period not_superhost': 0.0024859957518771013,
#  'security_deposit review_period not_superhost is_superhost': 0.0,
#  'security_deposit review_period not_superhost^2': 0.002465321551194157,
#  'security_deposit review_period^2': -7.701088110190191e-05,
#  'security_deposit review_period^2 is_superhost': 7.663885684487703e-05,
#  'security_deposit review_period^2 not_superhost': 7.64616677844311e-05,
#  'security_deposit review_period^3': -1.8130164036733731e-10,
#  'security_deposit review_scores_cleanliness': -0.3359426169351768,
#  'security_deposit review_scores_cleanliness is_superhost': -0.38399264874579425,
#  'security_deposit review_scores_cleanliness is_superhost^2': -0.3840051573787085,
#  'security_deposit review_scores_cleanliness not_superhost': 0.030743322718516014,
#  'security_deposit review_scores_cleanliness not_superhost is_superhost': 0.0,
#  'security_deposit review_scores_cleanliness not_superhost^2': 0.03074314468801042,
#  'security_deposit review_scores_cleanliness number_of_amenities': -0.0002796304429521911,
#  'security_deposit review_scores_cleanliness number_of_amenities is_superhost': 0.0006618045290589243,
#  'security_deposit review_scores_cleanliness number_of_amenities not_superhost': -0.0009413333710081971,
#  'security_deposit review_scores_cleanliness number_of_amenities review_period': 7.552931603290128e-06,
#  'security_deposit review_scores_cleanliness number_of_amenities^2': 0.00010040010903928635,
#  'security_deposit review_scores_cleanliness number_of_days_as_host': 0.00015615774626171662,
#  'security_deposit review_scores_cleanliness number_of_days_as_host is_superhost': 0.00011786195147781058,
#  'security_deposit review_scores_cleanliness number_of_days_as_host not_superhost': 3.450943296701607e-05,
#  'security_deposit review_scores_cleanliness number_of_days_as_host number_of_amenities': -2.2977554895140152e-06,
#  'security_deposit review_scores_cleanliness number_of_days_as_host review_period': 1.194065390808588e-07,
#  'security_deposit review_scores_cleanliness number_of_days_as_host^2': 1.19861422002987e-09,
#  'security_deposit review_scores_cleanliness rent_index': 9.176536309290508e-05,
#  'security_deposit review_scores_cleanliness rent_index is_superhost': -2.6903914586179478e-05,
#  'security_deposit review_scores_cleanliness rent_index not_superhost': 6.72938175626034e-05,
#  'security_deposit review_scores_cleanliness rent_index number_of_amenities': 5.288778915871399e-06,
#  'security_deposit review_scores_cleanliness rent_index number_of_days_as_host': 1.1813190255866024e-08,
#  'security_deposit review_scores_cleanliness rent_index review_period': 8.513176648610593e-08,
#  'security_deposit review_scores_cleanliness rent_index^2': -1.4064821444136066e-07,
#  'security_deposit review_scores_cleanliness review_period': 0.0007469608359694626,
#  'security_deposit review_scores_cleanliness review_period is_superhost': 0.00043255061604193174,
#  'security_deposit review_scores_cleanliness review_period not_superhost': 0.0003224363457341211,
#  'security_deposit review_scores_cleanliness review_period^2': -1.8546906482841408e-07,
#  'security_deposit review_scores_cleanliness^2': -0.008808330952025873,
#  'security_deposit review_scores_cleanliness^2 is_superhost': -0.0012139171897469706,
#  'security_deposit review_scores_cleanliness^2 not_superhost': -0.007573731701251792,
#  'security_deposit review_scores_cleanliness^2 number_of_amenities': 3.914130219617701e-05,
#  'security_deposit review_scores_cleanliness^2 number_of_days_as_host': -3.9078545192488195e-06,
#  'security_deposit review_scores_cleanliness^2 rent_index': 1.03923351412321e-05,
#  'security_deposit review_scores_cleanliness^2 review_period': -5.411579721610592e-05,
#  'security_deposit review_scores_cleanliness^3': -0.0005156642685242068,
#  'security_deposit^2': -0.0064425359523051905,
#  'security_deposit^2 cleaning_fee': 5.670471070308353e-06,
#  'security_deposit^2 cleaning_fee extra_people': -4.4817766951034963e-07,
#  'security_deposit^2 cleaning_fee guests_included': 1.1604751866370642e-06,
#  'security_deposit^2 cleaning_fee is_superhost': 1.1638679875285857e-05,
#  'security_deposit^2 cleaning_fee not_superhost': 2.0269068463760637e-05,
#  'security_deposit^2 cleaning_fee number_of_amenities': -3.5916886290490203e-07,
#  'security_deposit^2 cleaning_fee number_of_days_as_host': -9.22262292230025e-09,
#  'security_deposit^2 cleaning_fee number_of_reviews': 1.1065076023118129e-07,
#  'security_deposit^2 cleaning_fee rent_index': -3.876854564460741e-08,
#  'security_deposit^2 cleaning_fee review_period': -8.681104446406351e-10,
#  'security_deposit^2 cleaning_fee review_scores_cleanliness': 3.996418018018604e-06,
#  'security_deposit^2 cleaning_fee^2': -3.267924598136275e-08,
#  'security_deposit^2 extra_people': -1.8190019800873303e-05,
#  'security_deposit^2 extra_people is_superhost': -1.6182418180685377e-05,
#  'security_deposit^2 extra_people not_superhost': 1.1754298716547992e-05,
#  'security_deposit^2 extra_people number_of_amenities': -3.673712166158555e-08,
#  'security_deposit^2 extra_people number_of_days_as_host': -1.450077643551373e-08,
#  'security_deposit^2 extra_people number_of_reviews': -7.021319645703419e-09,
#  'security_deposit^2 extra_people rent_index': -3.2600450583855634e-08,
#  'security_deposit^2 extra_people review_period': 2.1107281132116962e-08,
#  'security_deposit^2 extra_people review_scores_cleanliness': -4.233130815249236e-06,
#  'security_deposit^2 extra_people^2': 9.617707293431058e-07,
#  'security_deposit^2 guests_included': -0.0004843287562701451,
#  'security_deposit^2 guests_included extra_people': -1.2535650801589912e-05,
#  'security_deposit^2 guests_included is_superhost': -0.00015878698851525493,
#  'security_deposit^2 guests_included not_superhost': -0.0003718520284497394,
#  'security_deposit^2 guests_included number_of_amenities': 1.7630824344798042e-05,
#  'security_deposit^2 guests_included number_of_days_as_host': 5.471836282645512e-08,
#  'security_deposit^2 guests_included number_of_reviews': -1.3790883242771773e-05,
#  'security_deposit^2 guests_included rent_index': 8.10485206177063e-07,
#  'security_deposit^2 guests_included review_period': 6.773796375163363e-07,
#  'security_deposit^2 guests_included review_scores_cleanliness': 5.1971647309857145e-05,
#  'security_deposit^2 guests_included^2': 3.153084617313289e-05,
#  'security_deposit^2 is_superhost': 0.005491432851369074,
#  'security_deposit^2 is_superhost^2': 0.005493022445584279,
#  'security_deposit^2 not_superhost': 0.0038486417397619464,
#  'security_deposit^2 not_superhost is_superhost': 0.0,
#  'security_deposit^2 not_superhost^2': 0.0038162297243220593,
#  'security_deposit^2 number_of_amenities': 8.75184968009823e-05,
#  'security_deposit^2 number_of_amenities is_superhost': 6.319877292119412e-05,
#  'security_deposit^2 number_of_amenities not_superhost': 7.09117114028564e-05,
#  'security_deposit^2 number_of_amenities review_period': 5.141085742885187e-10,
#  'security_deposit^2 number_of_amenities^2': -8.017749976637354e-07,
#  'security_deposit^2 number_of_days_as_host': -0.00012832333954600629,
#  'security_deposit^2 number_of_days_as_host is_superhost': 0.00013039253790725873,
#  'security_deposit^2 number_of_days_as_host not_superhost': 0.00013061008595612308,
#  'security_deposit^2 number_of_days_as_host number_of_amenities': 2.7126889987766356e-09,
#  'security_deposit^2 number_of_days_as_host review_period': 6.494255133659976e-11,
#  'security_deposit^2 number_of_days_as_host^2': 9.94633264639333e-11,
#  'security_deposit^2 number_of_reviews': 3.2064865553732424e-05,
#  'security_deposit^2 number_of_reviews is_superhost': 3.36812142975051e-05,
#  'security_deposit^2 number_of_reviews not_superhost': 4.175003883766474e-05,
#  'security_deposit^2 number_of_reviews number_of_amenities': 3.513272886013826e-07,
#  'security_deposit^2 number_of_reviews number_of_days_as_host': -1.8101635364253799e-09,
#  'security_deposit^2 number_of_reviews rent_index': -1.4870366705360683e-08,
#  'security_deposit^2 number_of_reviews review_period': 9.421489963190588e-09,
#  'security_deposit^2 number_of_reviews review_scores_cleanliness': -6.280149189077244e-07,
#  'security_deposit^2 number_of_reviews^2': 5.5003443608352826e-08,
#  'security_deposit^2 rent_index': -8.313306333693367e-05,
#  'security_deposit^2 rent_index is_superhost': 8.18693937843558e-05,
#  'security_deposit^2 rent_index not_superhost': 8.285120245246e-05,
#  'security_deposit^2 rent_index number_of_amenities': 2.317269208115813e-09,
#  'security_deposit^2 rent_index number_of_days_as_host': -1.3554328770482016e-09,
#  'security_deposit^2 rent_index review_period': 3.8432962368162293e-10,
#  'security_deposit^2 rent_index^2': -6.376649208661433e-10,
#  'security_deposit^2 review_period': -1.09910057339953e-05,
#  'security_deposit^2 review_period is_superhost': 2.0768113120145007e-05,
#  'security_deposit^2 review_period not_superhost': 2.033668282229849e-05,
#  'security_deposit^2 review_period^2': -1.135597782475628e-09,
#  'security_deposit^2 review_scores_cleanliness': -0.000509462192862916,
#  'security_deposit^2 review_scores_cleanliness is_superhost': -0.0003217356198294303,
#  'security_deposit^2 review_scores_cleanliness not_superhost': -0.000207573785346188,
#  'security_deposit^2 review_scores_cleanliness number_of_amenities': -1.6444140337864275e-05,
#  'security_deposit^2 review_scores_cleanliness number_of_days_as_host': -1.974697770752709e-08,
#  'security_deposit^2 review_scores_cleanliness rent_index': 3.6018217806237963e-07,
#  'security_deposit^2 review_scores_cleanliness review_period': -6.368586156280717e-07,
#  'security_deposit^2 review_scores_cleanliness^2': 6.11778902609389e-05,
#  'security_deposit^3': -5.361837497171103e-05,
#  'security_deposit^3 cleaning_fee': 9.27730210015243e-09,
#  'security_deposit^3 extra_people': 1.2484043103964948e-08,
#  'security_deposit^3 guests_included': -4.995998337261969e-07,
#  'security_deposit^3 is_superhost': 5.5902758289792375e-05,
#  'security_deposit^3 not_superhost': 5.505887195213665e-05,
#  'security_deposit^3 number_of_amenities': -7.120912723802136e-08,
#  'security_deposit^3 number_of_days_as_host': 9.916938936704867e-10,
#  'security_deposit^3 number_of_reviews': 2.1029560846180795e-08,
#  'security_deposit^3 rent_index': 1.6828177740180195e-10,
#  'security_deposit^3 review_period': -1.1425346502225153e-09,
#  'security_deposit^3 review_scores_cleanliness': 1.3887254787889759e-07,
#  'security_deposit^4': -1.0154622420710524e-09}

# %%
pprint.pprint(sorted(dict(zip(poly_features.get_feature_names(list(X.columns)),poly_model3_coef)).items(), key=lambda kv:kv[1]))
# Out:
# [('guests_included review_scores_cleanliness', -95.84692273372256),
#  ('accommodates beds is_superhost^2', -87.35739488838313),
#  ('accommodates beds is_superhost', -87.35726757476323),
#  ('bathrooms guests_included^2', -82.59159759757642),
#  ('guests_included review_scores_cleanliness is_superhost', -74.12023287852715),
#  ('guests_included review_scores_cleanliness is_superhost^2',
#   -74.12022257004568),
#  ('bedrooms^2 not_superhost^2', -72.2292222458426),
#  ('bedrooms^2 not_superhost', -72.2291922098124),
#  ('bedrooms^2 beds', -68.03544598909914),
#  ('accommodates bedrooms not_superhost', -65.21070086523336),
#  ('accommodates bedrooms not_superhost^2', -65.21069232931875),
#  ('host_response_rate', -64.8585702833838),
#  ('bathrooms number_of_amenities', -62.450913063356495),
#  ('bathrooms^3', -61.60775803188805),
#  ('beds^2', -60.5614332608087),
#  ('bedrooms beds guests_included', -57.30349366035393),
#  ('bathrooms bedrooms review_scores_cleanliness', -56.30670856364064),
#  ('accommodates bedrooms', -54.888905738159416),
#  ('bathrooms number_of_reviews', -52.52492884268561),
#  ('bedrooms^2 beds is_superhost', -52.33428912030333),
#  ('bedrooms beds', -49.24597809514285),
#  ('bedrooms review_scores_cleanliness not_superhost', -48.98372012411559),
#  ('bedrooms review_scores_cleanliness not_superhost^2', -48.9836565502578),
#  ('accommodates bathrooms not_superhost^2', -48.86393599607517),
#  ('accommodates bathrooms not_superhost', -48.8633155838176),
#  ('accommodates beds', -48.44027715734995),
#  ('accommodates bedrooms guests_included', -46.67267510177363),
#  ('bathrooms guests_included^2 not_superhost', -44.725721224133636),
#  ('bathrooms^3 is_superhost', -44.60657274693614),
#  ('bathrooms number_of_amenities not_superhost', -44.12472730265729),
#  ('bathrooms number_of_amenities not_superhost^2', -44.12469398494907),
#  ('bathrooms bedrooms^2 is_superhost', -43.44245246437071),
#  ('bathrooms^2 bedrooms is_superhost', -42.18658750133321),
#  ('bedrooms beds guests_included not_superhost', -42.13965097577135),
#  ('accommodates bathrooms beds', -41.24391227976281),
#  ('accommodates bathrooms beds is_superhost', -40.15734667295217),
#  ('accommodates bedrooms beds', -38.75564545577246),
#  ('bedrooms beds not_superhost', -38.44681079872506),
#  ('bedrooms beds not_superhost^2', -38.44680990815942),
#  ('beds^2 is_superhost', -38.09367081199381),
#  ('beds^2 is_superhost^2', -38.09365461205369),
#  ('bedrooms review_scores_cleanliness', -37.98747043080298),
#  ('bathrooms guests_included^2 is_superhost', -37.86588498763654),
#  ('bathrooms bedrooms review_scores_cleanliness not_superhost',
#   -37.65854137780166),
#  ('bedrooms beds review_scores_cleanliness is_superhost', -36.59887617324163),
#  ('bedrooms beds review_scores_cleanliness', -36.47910183714464),
#  ('bathrooms^2 bedrooms beds', -36.242444858539145),
#  ('accommodates bedrooms beds not_superhost', -35.767061985921345),
#  ('bathrooms^2 review_scores_cleanliness is_superhost', -35.765080289898144),
#  ('bathrooms review_scores_cleanliness is_superhost', -35.54831077898702),
#  ('bathrooms review_scores_cleanliness is_superhost^2', -35.54824824258144),
#  ('bedrooms^2', -33.97288011539984),
#  ('bathrooms^2 review_scores_cleanliness', -33.839523136141246),
#  ('guests_included number_of_amenities', -32.095005966479),
#  ('bathrooms^2 beds is_superhost', -30.40990454904909),
#  ('accommodates bathrooms^2 not_superhost', -30.138944563538853),
#  ('host_response_rate is_superhost', -30.121200219384274),
#  ('host_response_rate is_superhost^3', -29.462147123866323),
#  ('host_response_rate is_superhost^2', -29.46203011271968),
#  ('bathrooms number_of_reviews is_superhost', -28.71402015089146),
#  ('bathrooms number_of_reviews is_superhost^2', -28.71398567685019),
#  ('accommodates bedrooms guests_included is_superhost', -27.998683083626865),
#  ('host_response_rate not_superhost^2', -26.932393340744067),
#  ('host_response_rate not_superhost^3', -26.931547331162363),
#  ('bathrooms beds^2 not_superhost', -26.66081721755977),
#  ('beds guests_included is_superhost^2', -26.084658580390652),
#  ('beds guests_included is_superhost', -26.08464199198869),
#  ('host_response_rate not_superhost', -26.028349576787853),
#  ('accommodates number_of_amenities', -25.22904894046938),
#  ('extra_people', -25.138715889026336),
#  ('accommodates bathrooms guests_included', -24.71731359988065),
#  ('rent_index', -24.18046896983163),
#  ('bathrooms number_of_reviews not_superhost', -23.811361799847127),
#  ('bathrooms number_of_reviews not_superhost^2', -23.81126149127119),
#  ('extra_people not_superhost^3', -23.79850856056579),
#  ('extra_people not_superhost^2', -23.79850414255108),
#  ('extra_people not_superhost', -23.78330566641289),
#  ('accommodates bathrooms review_scores_cleanliness is_superhost',
#   -23.417579549998266),
#  ('beds^2 not_superhost^2', -22.535560303421455),
#  ('beds^2 not_superhost', -22.535556515117616),
#  ('accommodates bathrooms bedrooms not_superhost', -22.007251326783972),
#  ('guests_included review_scores_cleanliness not_superhost',
#   -21.756325892394813),
#  ('guests_included review_scores_cleanliness not_superhost^2',
#   -21.75631037672522),
#  ('beds^2 guests_included', -20.96526160827048),
#  ('bathrooms^2 bedrooms guests_included', -20.80510249057394),
#  ('bathrooms bedrooms^2 guests_included', -20.497293482573273),
#  ('bathrooms^2 extra_people', -20.425380959500092),
#  ('bedrooms^2 beds guests_included', -20.116237633616098),
#  ('review_scores_cleanliness^2', -20.002794267304417),
#  ('guests_included number_of_amenities is_superhost^2', -19.038110684311853),
#  ('guests_included number_of_amenities is_superhost', -19.0381101828494),
#  ('bathrooms^2 beds guests_included', -18.82622424678724),
#  ('accommodates bedrooms guests_included not_superhost', -18.674403795981412),
#  ('bathrooms bedrooms review_scores_cleanliness is_superhost',
#   -18.648380195904963),
#  ('accommodates bathrooms', -18.496773721648644),
#  ('bathrooms number_of_amenities is_superhost^2', -18.391354918852358),
#  ('bathrooms number_of_amenities is_superhost', -18.39127892488128),
#  ('bathrooms^3 not_superhost', -17.001448758590374),
#  ('bathrooms bedrooms^2 beds', -16.99698725514164),
#  ('bathrooms^2 not_superhost^2', -16.32350401629019),
#  ('bathrooms^2 not_superhost', -16.323261284157187),
#  ('bathrooms bedrooms not_superhost^2', -16.064439108745162),
#  ('bathrooms bedrooms not_superhost', -16.06424177335655),
#  ('bathrooms bedrooms beds is_superhost', -16.004109523019046),
#  ('accommodates bathrooms bedrooms^2', -15.86512928177107),
#  ('bedrooms^2 beds not_superhost', -15.701216006222772),
#  ('accommodates bathrooms review_scores_cleanliness', -15.61300154523809),
#  ('bedrooms beds guests_included is_superhost', -15.163755236698421),
#  ('beds^2 guests_included is_superhost', -15.070330195120025),
#  ('guests_included number_of_reviews', -14.922699492574935),
#  ('accommodates bathrooms guests_included is_superhost', -13.494877422811056),
#  ('beds^3', -13.436164060359676),
#  ('guests_included number_of_amenities not_superhost', -13.04143475062589),
#  ('guests_included number_of_amenities not_superhost^2', -13.041417316780933),
#  ('accommodates number_of_amenities is_superhost^2', -12.978065428365781),
#  ('accommodates number_of_amenities is_superhost', -12.97779561998952),
#  ('accommodates guests_included review_scores_cleanliness',
#   -12.672464009529438),
#  ('bathrooms beds not_superhost^2', -12.446790593877427),
#  ('bathrooms beds not_superhost', -12.446602009516537),
#  ('bathrooms review_scores_cleanliness^2', -12.342078404893037),
#  ('accommodates bathrooms^2', -12.197921757065675),
#  ('beds^2 review_scores_cleanliness', -12.192837791859304),
#  ('accommodates number_of_amenities not_superhost^2', -12.0682802792185),
#  ('accommodates number_of_amenities not_superhost', -12.068122123311595),
#  ('rent_index not_superhost^3', -11.953895437305299),
#  ('rent_index not_superhost^2', -11.953892017992365),
#  ('rent_index not_superhost', -11.948966287592288),
#  ('bathrooms^2 extra_people is_superhost', -11.71894769887703),
#  ('bathrooms beds number_of_amenities', -11.647873718892335),
#  ('accommodates bedrooms^3', -11.473378271940119),
#  ('bedrooms^2 beds^2', -11.447989886473048),
#  ('bedrooms guests_included is_superhost^2', -11.31107303761709),
#  ('bedrooms guests_included is_superhost', -11.311051444987484),
#  ('rent_index is_superhost^2', -11.233831719559825),
#  ('rent_index is_superhost^3', -11.233830390856511),
#  ('rent_index is_superhost', -11.224402093563626),
#  ('accommodates bathrooms guests_included not_superhost', -11.222805111924963),
#  ('bathrooms beds', -10.935533864286358),
#  ('bedrooms beds is_superhost', -10.761494582680491),
#  ('bedrooms beds is_superhost^2', -10.761314748187797),
#  ('bathrooms bedrooms^2 review_scores_cleanliness', -10.750389465847967),
#  ('bedrooms^3 not_superhost', -10.637901955171891),
#  ('bathrooms guests_included review_scores_cleanliness is_superhost',
#   -10.395303215913724),
#  ('accommodates guests_included review_scores_cleanliness is_superhost',
#   -10.146187274573723),
#  ('accommodates guests_included', -10.05705258459809),
#  ('review_scores_cleanliness^2 not_superhost^2', -10.029027943598907),
#  ('review_scores_cleanliness^2 not_superhost', -10.029025889279643),
#  ('bedrooms beds extra_people', -9.998798096869956),
#  ('review_scores_cleanliness^2 is_superhost', -9.989962476902146),
#  ('review_scores_cleanliness^2 is_superhost^2', -9.98995985631793),
#  ('review_scores_cleanliness not_superhost^3', -9.971420544815714),
#  ('review_scores_cleanliness not_superhost^2', -9.971416175174713),
#  ('review_scores_cleanliness not_superhost', -9.967516383354782),
#  ('guests_included number_of_reviews is_superhost^2', -9.787913720126854),
#  ('guests_included number_of_reviews is_superhost', -9.787913315274697),
#  ('bathrooms^3 beds', -9.639595919660978),
#  ('host_response_rate bathrooms beds', -9.530523029109217),
#  ('accommodates bathrooms^3', -9.497969145281811),
#  ('accommodates bathrooms bedrooms beds', -9.482157211417293),
#  ('accommodates guests_included not_superhost^2', -9.113188493220102),
#  ('accommodates guests_included not_superhost', -9.11308030758379),
#  ('beds^2 review_scores_cleanliness not_superhost', -9.016268538242311),
#  ('security_deposit', -8.782068633353227),
#  ('bathrooms^2 extra_people not_superhost', -8.706493270355157),
#  ('accommodates^2 bedrooms is_superhost', -8.441726034599796),
#  ('beds guests_included', -8.305821892594624),
#  ('bathrooms cleaning_fee is_superhost', -8.273683831122614),
#  ('bathrooms cleaning_fee is_superhost^2', -8.273582909535362),
#  ('bathrooms review_scores_cleanliness^2 is_superhost', -8.123996532237836),
#  ('host_response_rate bathrooms beds is_superhost', -7.858994804369633),
#  ('guests_included is_superhost', -7.554272367493531),
#  ('guests_included is_superhost^3', -7.544814289100517),
#  ('guests_included is_superhost^2', -7.544806796817994),
#  ('accommodates bathrooms beds^2', -7.220295304996891),
#  ('beds^3 not_superhost', -7.183198542423207),
#  ('bedrooms^2 guests_included review_scores_cleanliness', -7.061440076623143),
#  ('bedrooms beds extra_people is_superhost', -7.01518106434493),
#  ('accommodates bedrooms number_of_amenities', -6.963284144662655),
#  ('bathrooms beds number_of_amenities not_superhost', -6.8770530680884105),
#  ('bathrooms beds^2', -6.70714715856132),
#  ('accommodates', -6.332765028575909),
#  ('beds^3 is_superhost', -6.252918013998506),
#  ('bedrooms', -6.226123982648698),
#  ('number_of_reviews review_scores_cleanliness', -6.101453024602836),
#  ('bathrooms bedrooms number_of_reviews', -6.052348923351517),
#  ('beds^2 guests_included not_superhost', -5.894948896040516),
#  ('bedrooms beds number_of_reviews', -5.85102314257826),
#  ('accommodates beds number_of_reviews', -5.642656989606456),
#  ('accommodates bedrooms review_scores_cleanliness not_superhost',
#   -5.516070446434579),
#  ('bathrooms beds^2 guests_included', -5.408863319419978),
#  ('accommodates bedrooms^2 guests_included', -5.199581892232827),
#  ('guests_included number_of_reviews not_superhost', -5.169936763850058),
#  ('guests_included number_of_reviews not_superhost^2', -5.169933396984739),
#  ('host_response_rate accommodates', -5.111527149724577),
#  ('guests_included extra_people', -5.0551260072298145),
#  ('bathrooms^2 beds review_scores_cleanliness', -5.046984300119115),
#  ('bathrooms^2', -4.903989692656004),
#  ('bedrooms number_of_reviews review_scores_cleanliness', -4.886078534735037),
#  ('bathrooms beds number_of_amenities is_superhost', -4.770666804844473),
#  ('beds review_scores_cleanliness is_superhost', -4.721800403320759),
#  ('beds review_scores_cleanliness is_superhost^2', -4.721791702503087),
#  ('accommodates^2 bathrooms^2', -4.651732873795361),
#  ('accommodates^2 beds not_superhost', -4.589807229134423),
#  ('host_response_rate beds guests_included', -4.534190538231514),
#  ('guests_included extra_people is_superhost^2', -4.420938614370113),
#  ('guests_included extra_people is_superhost', -4.420925524623997),
#  ('accommodates^2 guests_included', -4.4209196212759085),
#  ('beds review_scores_cleanliness^2', -4.410737588848716),
#  ('bedrooms^2 number_of_amenities', -4.24295008016219),
#  ('bathrooms beds^2 review_scores_cleanliness', -4.231587862699083),
#  ('bathrooms review_scores_cleanliness^2 not_superhost', -4.21800028571986),
#  ('bathrooms bedrooms number_of_reviews is_superhost', -3.8287082911109276),
#  ('accommodates^2 guests_included not_superhost', -3.8184905458702922),
#  ('bathrooms bedrooms extra_people', -3.734082525421799),
#  ('host_response_rate bathrooms^2 not_superhost', -3.690345533313808),
#  ('accommodates bedrooms number_of_amenities is_superhost', -3.638747637911918),
#  ('bedrooms guests_included^2 review_scores_cleanliness', -3.6219549626557366),
#  ('accommodates not_superhost', -3.5328637963372302),
#  ('bathrooms cleaning_fee', -3.497386997042707),
#  ('accommodates bedrooms guests_included^2', -3.445017045046774),
#  ('accommodates^3', -3.4395400326696026),
#  ('accommodates not_superhost^3', -3.4227333237819138),
#  ('accommodates not_superhost^2', -3.4226243773616916),
#  ('security_deposit is_superhost^2', -3.4085804323392015),
#  ('security_deposit is_superhost^3', -3.4085592323534977),
#  ('security_deposit is_superhost', -3.406793647558459),
#  ('bedrooms guests_included^3', -3.3998483451586385),
#  ('number_of_reviews review_scores_cleanliness not_superhost^2',
#   -3.3417425234173503),
#  ('number_of_reviews review_scores_cleanliness not_superhost',
#   -3.3417389673109152),
#  ('accommodates bedrooms number_of_amenities not_superhost',
#   -3.3250338535092157),
#  ('bedrooms guests_included number_of_amenities', -3.2961485751849553),
#  ('accommodates guests_included number_of_amenities', -3.2818331207158415),
#  ('accommodates^2 beds', -3.2751542077644835),
#  ('number_of_amenities is_superhost', -3.2536686765867695),
#  ('number_of_amenities is_superhost^2', -3.2453943236246796),
#  ('number_of_amenities is_superhost^3', -3.2453928951357445),
#  ('accommodates bathrooms guests_included^2', -3.2414857552238066),
#  ('accommodates beds extra_people', -3.2330682704794143),
#  ('beds^2 review_scores_cleanliness is_superhost', -3.176533686849985),
#  ('security_deposit not_superhost', -3.163099583442343),
#  ('security_deposit not_superhost^3', -3.1516768355465117),
#  ('security_deposit not_superhost^2', -3.151663292102499),
#  ('beds number_of_reviews', -3.0880750363649043),
#  ('bedrooms beds number_of_reviews is_superhost', -3.083913969592362),
#  ('beds review_scores_cleanliness^2 is_superhost', -3.032055296991789),
#  ('bathrooms bedrooms guests_included review_scores_cleanliness',
#   -3.031109725886841),
#  ('accommodates bedrooms beds is_superhost', -2.9887000955136176),
#  ('bedrooms beds extra_people not_superhost', -2.983689705436509),
#  ('review_scores_cleanliness number_of_amenities not_superhost^2',
#   -2.9615472521545545),
#  ('review_scores_cleanliness number_of_amenities not_superhost',
#   -2.9615340077584333),
#  ('bathrooms bedrooms extra_people not_superhost', -2.950703757624905),
#  ('host_response_rate bathrooms^2 guests_included', -2.9394256230835794),
#  ('guests_included^2 review_scores_cleanliness', -2.934446733855872),
#  ('accommodates bathrooms guests_included review_scores_cleanliness',
#   -2.9076256377255296),
#  ('accommodates beds^2 guests_included', -2.84950604934953),
#  ('bathrooms beds guests_included^2', -2.8489193908848973),
#  ('accommodates beds number_of_reviews not_superhost', -2.8214059213033003),
#  ('accommodates beds number_of_reviews is_superhost', -2.820780066978603),
#  ('beds guests_included^3', -2.7825096294986547),
#  ('accommodates review_scores_cleanliness^2', -2.7738831977818035),
#  ('bedrooms beds number_of_reviews not_superhost', -2.7671425259547373),
#  ('bedrooms number_of_reviews review_scores_cleanliness is_superhost',
#   -2.766181127639293),
#  ('number_of_reviews review_scores_cleanliness is_superhost',
#   -2.762696913475622),
#  ('number_of_reviews review_scores_cleanliness is_superhost^2',
#   -2.762689610523827),
#  ('bedrooms cleaning_fee', -2.7427098016557174),
#  ('host_response_rate accommodates is_superhost^2', -2.7372055844592746),
#  ('host_response_rate accommodates is_superhost', -2.7345520007108095),
#  ('host_response_rate beds guests_included is_superhost', -2.723532744323484),
#  ('bedrooms beds cleaning_fee', -2.6719406372508923),
#  ('beds extra_people', -2.656471802761928),
#  ('bathrooms', -2.6368712759995736),
#  ('accommodates bathrooms^2 review_scores_cleanliness', -2.586703824655709),
#  ('bedrooms not_superhost^2', -2.5767291811437776),
#  ('bedrooms not_superhost^3', -2.57671083597367),
#  ('accommodates guests_included review_scores_cleanliness not_superhost',
#   -2.5261120529103938),
#  ('guests_included', -2.4943561833643897),
#  ('accommodates bathrooms number_of_reviews', -2.476639034520401),
#  ('bedrooms not_superhost', -2.46462461538019),
#  ('accommodates is_superhost^2', -2.456792176395283),
#  ('accommodates is_superhost^3', -2.4566870100485394),
#  ('bedrooms^2 number_of_amenities not_superhost', -2.4331047385324003),
#  ('host_response_rate bedrooms beds not_superhost', -2.4327729857712335),
#  ('accommodates^2 bedrooms review_scores_cleanliness', -2.430613570358299),
#  ('bathrooms^2 number_of_reviews', -2.4082530765081094),
#  ('number_of_days_as_host', -2.4074469163104646),
#  ('accommodates^2 bathrooms guests_included', -2.3341376576160373),
#  ('beds is_superhost', -2.320720902156402),
#  ('beds is_superhost^3', -2.319051505552678),
#  ('beds is_superhost^2', -2.319049904037474),
#  ('accommodates guests_included^2 is_superhost', -2.276358492486248),
#  ('accommodates number_of_reviews review_scores_cleanliness',
#   -2.249137363022843),
#  ('beds not_superhost^2', -2.242318022816992),
#  ('beds not_superhost^3', -2.242303248416961),
#  ('beds not_superhost', -2.2387799237783383),
#  ('bathrooms bedrooms number_of_reviews not_superhost', -2.2238757412664816),
#  ('host_response_rate accommodates bedrooms is_superhost', -2.2207641477089743),
#  ('accommodates is_superhost', -2.20198417251447),
#  ('beds number_of_reviews not_superhost', -2.2005561283792954),
#  ('beds number_of_reviews not_superhost^2', -2.200527488045897),
#  ('accommodates guests_included number_of_amenities is_superhost',
#   -2.186686783009195),
#  ('bedrooms number_of_reviews review_scores_cleanliness not_superhost',
#   -2.119884602927063),
#  ('bathrooms bedrooms cleaning_fee', -2.116672591936223),
#  ('bedrooms guests_included number_of_reviews', -2.1014373741938455),
#  ('accommodates^3 not_superhost', -2.0028092148165935),
#  ('beds cleaning_fee guests_included', -1.995755541903702),
#  ('guests_included^2 review_scores_cleanliness not_superhost',
#   -1.9956758480523369),
#  ('bedrooms cleaning_fee is_superhost', -1.982971117959626),
#  ('bedrooms cleaning_fee is_superhost^2', -1.9829365616383632),
#  ('bathrooms beds^2 number_of_amenities', -1.9714007871530654),
#  ('review_period is_superhost^3', -1.969526688541718),
#  ('review_period is_superhost^2', -1.9695220297394231),
#  ('accommodates bedrooms beds^2', -1.96530137187796),
#  ('review_period is_superhost', -1.9556814543917247),
#  ('accommodates bathrooms cleaning_fee', -1.9374149188959928),
#  ('accommodates beds extra_people not_superhost', -1.867061835672021),
#  ('accommodates bathrooms beds guests_included', -1.8385548592556655),
#  ('host_response_rate beds guests_included not_superhost', -1.8106934022221783),
#  ('bedrooms^2 number_of_amenities is_superhost', -1.809778106245268),
#  ('host_response_rate bedrooms review_scores_cleanliness is_superhost',
#   -1.8087488348610021),
#  ('bedrooms beds guests_included review_scores_cleanliness',
#   -1.7809184947922332),
#  ('review_period', -1.7729602106216038),
#  ('bathrooms^3 review_scores_cleanliness', -1.7721213666702946),
#  ('review_scores_cleanliness', -1.7375014493054897),
#  ('bathrooms bedrooms beds number_of_amenities', -1.7314369077592278),
#  ('accommodates review_scores_cleanliness^2 is_superhost', -1.7290601930110525),
#  ('bedrooms guests_included number_of_amenities not_superhost',
#   -1.701301045906681),
#  ('accommodates bathrooms review_scores_cleanliness^2', -1.6897159093771597),
#  ('accommodates beds guests_included review_scores_cleanliness',
#   -1.6839692138763602),
#  ('bathrooms^2 guests_included number_of_amenities', -1.6782394399381932),
#  ('host_response_rate bathrooms beds not_superhost', -1.6757389906914153),
#  ('accommodates bathrooms number_of_reviews is_superhost', -1.6505392195510487),
#  ('bedrooms^2 review_scores_cleanliness^2', -1.6447544910573644),
#  ('bathrooms bedrooms', -1.644753645040558),
#  ('host_response_rate beds not_superhost^2', -1.6266205696099127),
#  ('host_response_rate beds not_superhost', -1.6249544998603958),
#  ('accommodates^2 review_scores_cleanliness is_superhost', -1.6237484491350584),
#  ('accommodates beds^2 is_superhost', -1.6224772715994702),
#  ('host_response_rate bathrooms bedrooms not_superhost', -1.622059417415407),
#  ('accommodates beds review_scores_cleanliness is_superhost',
#   -1.6201815263485653),
#  ('accommodates bedrooms^2 number_of_amenities', -1.6144397013040512),
#  ('beds review_period', -1.6070058380645618),
#  ('bedrooms guests_included number_of_reviews is_superhost',
#   -1.6035937048195505),
#  ('bathrooms^2 number_of_reviews is_superhost', -1.6019282848359793),
#  ('host_response_rate bedrooms is_superhost^2', -1.5967992680345457),
#  ('host_response_rate bedrooms is_superhost', -1.5961575877192915),
#  ('bedrooms beds cleaning_fee is_superhost', -1.5952021746633556),
#  ('bedrooms guests_included number_of_amenities is_superhost',
#   -1.5948828131619743),
#  ('extra_people is_superhost^3', -1.5761038208004345),
#  ('extra_people is_superhost^2', -1.5760982155382721),
#  ('extra_people is_superhost', -1.573900318665503),
#  ('accommodates^2 bedrooms beds', -1.572492172043639),
#  ('accommodates^2 guests_included^2', -1.5182746361206239),
#  ('bedrooms review_period', -1.5075652677662887),
#  ('accommodates beds^2 review_scores_cleanliness', -1.4868608598115174),
#  ('bathrooms bedrooms cleaning_fee is_superhost', -1.4672751383984375),
#  ('host_response_rate bathrooms review_scores_cleanliness not_superhost',
#   -1.4597339947871664),
#  ('beds extra_people not_superhost^2', -1.4526004340871885),
#  ('beds extra_people not_superhost', -1.4525963250540617),
#  ('accommodates^3 is_superhost', -1.4383280262735456),
#  ('accommodates bathrooms extra_people', -1.3862218097682153),
#  ('beds review_scores_cleanliness^2 not_superhost', -1.3786613891719772),
#  ('host_response_rate bathrooms guests_included not_superhost',
#   -1.377618311437003),
#  ('bathrooms^3 number_of_amenities', -1.374397437203254),
#  ('accommodates beds extra_people is_superhost', -1.3664700516803325),
#  ('bedrooms extra_people review_scores_cleanliness', -1.353469609780388),
#  ('accommodates bathrooms cleaning_fee is_superhost', -1.349221856182273),
#  ('bathrooms bedrooms review_scores_cleanliness number_of_amenities',
#   -1.298647215549715),
#  ('bathrooms extra_people review_scores_cleanliness', -1.2962277811888625),
#  ('host_response_rate bedrooms^2 is_superhost', -1.2681562582237194),
#  ('accommodates^2 review_scores_cleanliness', -1.2563148108920257),
#  ('accommodates bathrooms extra_people is_superhost', -1.2495203556915169),
#  ('bathrooms^3 extra_people', -1.2484034100986812),
#  ('beds extra_people is_superhost', -1.1804307216047154),
#  ('beds extra_people is_superhost^2', -1.1803965311780922),
#  ('accommodates number_of_reviews review_scores_cleanliness not_superhost',
#   -1.1274798429741433),
#  ('beds cleaning_fee guests_included not_superhost', -1.1272643851515625),
#  ('accommodates number_of_reviews review_scores_cleanliness is_superhost',
#   -1.1214762363826538),
#  ('host_response_rate accommodates^2', -1.1153682520379946),
#  ('beds review_period is_superhost^2', -1.108729938339835),
#  ('beds review_period is_superhost', -1.1087204785898126),
#  ('beds review_scores_cleanliness number_of_amenities', -1.1067859580632393),
#  ('guests_included^2 extra_people', -1.0995121046542593),
#  ('host_response_rate bathrooms^2 bedrooms', -1.0945454525621623),
#  ('accommodates guests_included number_of_amenities not_superhost',
#   -1.0945401588811503),
#  ('accommodates bathrooms beds not_superhost', -1.085997432557341),
#  ('bedrooms beds cleaning_fee not_superhost', -1.0766872528571874),
#  ('bedrooms beds guests_included number_of_amenities', -1.0735857087519223),
#  ('accommodates^2 bedrooms', -1.0599999948176753),
#  ('accommodates bathrooms^2 number_of_amenities', -1.0563852364994102),
#  ('host_response_rate bedrooms guests_included', -1.0531314912094722),
#  ('bedrooms extra_people not_superhost', -1.0515181651061747),
#  ('bedrooms extra_people not_superhost^2', -1.0514252432393643),
#  ('bedrooms review_period not_superhost^2', -1.0502382644539432),
#  ('bedrooms review_period not_superhost', -1.0502331441223713),
#  ('accommodates review_scores_cleanliness^2 not_superhost', -1.044757994154355),
#  ('accommodates guests_included extra_people', -1.0432163595747632),
#  ('accommodates^2 bedrooms guests_included', -1.042627312766992),
#  ('cleaning_fee guests_included not_superhost^2', -1.042060513264049),
#  ('cleaning_fee guests_included not_superhost', -1.0420367180491534),
#  ('beds', -1.0212483449735883),
#  ('bathrooms bedrooms guests_included extra_people', -1.0050503061998182),
#  ('accommodates bathrooms bedrooms extra_people', -0.9953307691028829),
#  ('bedrooms guests_included review_scores_cleanliness^2', -0.9449546632120391),
#  ('guests_included^2 review_scores_cleanliness is_superhost',
#   -0.9387799351371471),
#  ('bedrooms cleaning_fee not_superhost', -0.915872790016149),
#  ('bedrooms cleaning_fee not_superhost^2', -0.9158478732385319),
#  ('accommodates^3 beds', -0.9156652732380116),
#  ('beds number_of_reviews is_superhost', -0.9084255930848865),
#  ('beds number_of_reviews is_superhost^2', -0.9084063329749218),
#  ('bathrooms^2 beds cleaning_fee', -0.8861895792329968),
#  ('host_response_rate accommodates bathrooms bedrooms', -0.8793075879855985),
#  ('bathrooms guests_included review_scores_cleanliness^2', -0.876935990092181),
#  ('beds cleaning_fee guests_included is_superhost', -0.868466084824924),
#  ('bathrooms is_superhost^2', -0.8672097511133352),
#  ('bathrooms is_superhost^3', -0.8672008737085605),
#  ('bathrooms is_superhost', -0.8528682298366671),
#  ('host_response_rate bedrooms review_scores_cleanliness', -0.8463752403580322),
#  ('accommodates guests_included is_superhost^2', -0.8308608390689821),
#  ('accommodates guests_included is_superhost', -0.830844499573454),
#  ('accommodates bathrooms number_of_reviews not_superhost',
#   -0.8255630709877431),
#  ('guests_included review_scores_cleanliness^2 not_superhost',
#   -0.8168569649722836),
#  ('bathrooms^2 number_of_reviews not_superhost', -0.8063002461778043),
#  ('beds review_scores_cleanliness number_of_amenities is_superhost',
#   -0.8031647415358445),
#  ('bedrooms guests_included^2 number_of_amenities', -0.8006987399881794),
#  ('bathrooms beds^3', -0.7931066238957452),
#  ('bathrooms bedrooms extra_people is_superhost', -0.783209050617615),
#  ('host_response_rate accommodates^2 is_superhost', -0.7795161916182924),
#  ('bedrooms^3 review_scores_cleanliness', -0.7702754101061313),
#  ('bedrooms extra_people review_scores_cleanliness is_superhost',
#   -0.7531194098707719),
#  ('accommodates beds^2 number_of_amenities', -0.7469006576209959),
#  ('accommodates bathrooms beds extra_people', -0.7464991875350595),
#  ('accommodates beds^3', -0.7407716004308371),
#  ('host_response_rate bedrooms guests_included not_superhost',
#   -0.7379867143652135),
#  ('guests_included review_scores_cleanliness^2', -0.7224474667056979),
#  ('host_response_rate accommodates beds guests_included', -0.6771609128872712),
#  ('bathrooms review_scores_cleanliness review_period', -0.6652600758350389),
#  ('bathrooms beds guests_included extra_people', -0.6646701978845828),
#  ('guests_included extra_people not_superhost', -0.6640766037673327),
#  ('guests_included extra_people not_superhost^2', -0.6640665249500561),
#  ('accommodates guests_included extra_people not_superhost',
#   -0.6634477446164165),
#  ('bathrooms extra_people review_scores_cleanliness is_superhost',
#   -0.6624286710225615),
#  ('bathrooms bedrooms cleaning_fee not_superhost', -0.6493254352935209),
#  ('host_response_rate bathrooms is_superhost^2', -0.6402272940741883),
#  ('bathrooms bedrooms review_period', -0.639504015977571),
#  ('host_response_rate bathrooms is_superhost', -0.6367465076701821),
#  ('bathrooms extra_people review_scores_cleanliness not_superhost',
#   -0.633797259979515),
#  ('bathrooms beds extra_people review_scores_cleanliness', -0.6200186612463932),
#  ('beds guests_included number_of_reviews review_scores_cleanliness',
#   -0.6126983045985509),
#  ('beds number_of_amenities^2', -0.6126905970174035),
#  ('accommodates^2 number_of_reviews', -0.607866209092132),
#  ('bathrooms review_scores_cleanliness number_of_amenities',
#   -0.604951708016635),
#  ('guests_included^2 not_superhost', -0.6049325853724453),
#  ('guests_included^2 not_superhost^2', -0.6049303658304233),
#  ('accommodates^2 guests_included is_superhost', -0.6020984030181776),
#  ('bedrooms extra_people review_scores_cleanliness not_superhost',
#   -0.6004178921384962),
#  ('host_response_rate accommodates beds not_superhost', -0.5987891976369091),
#  ('beds review_scores_cleanliness^3', -0.5961978878548231),
#  ('guests_included^2 extra_people not_superhost', -0.5956555612741185),
#  ('bedrooms^2 guests_included extra_people', -0.5923664141849406),
#  ('accommodates bathrooms cleaning_fee not_superhost', -0.5895099274392337),
#  ('bathrooms bedrooms guests_included number_of_reviews', -0.5877736814355968),
#  ('host_response_rate accommodates not_superhost^2', -0.5819279461773641),
#  ('bedrooms review_period is_superhost^2', -0.5812423984216807),
#  ('bedrooms review_period is_superhost', -0.5812322591686722),
#  ('host_response_rate accommodates not_superhost', -0.5784358427938848),
#  ('beds review_period not_superhost^2', -0.5667347849728335),
#  ('beds review_period not_superhost', -0.5667297039257474),
#  ('bathrooms review_scores_cleanliness number_of_amenities not_superhost',
#   -0.5535352473398488),
#  ('bathrooms^3 cleaning_fee', -0.5520800515621911),
#  ('accommodates bathrooms^2 extra_people', -0.5503096031191305),
#  ('host_response_rate number_of_amenities', -0.545421593183),
#  ('bathrooms guests_included number_of_reviews not_superhost',
#   -0.5420280114360316),
#  ('bedrooms^2 extra_people', -0.5354010104323386),
#  ('bathrooms^2 cleaning_fee guests_included', -0.5129651925085339),
#  ('bathrooms cleaning_fee number_of_amenities', -0.5104452499975298),
#  ('accommodates bedrooms beds cleaning_fee', -0.5083619102743964),
#  ('guests_included^2 extra_people is_superhost', -0.5038465156747716),
#  ('bathrooms^2 beds extra_people', -0.5011048449482867),
#  ('bedrooms beds^2 number_of_amenities', -0.5003867113313677),
#  ('bedrooms guests_included number_of_reviews not_superhost',
#   -0.4979555892595903),
#  ('bathrooms extra_people number_of_amenities', -0.4869760450737499),
#  ('beds guests_included extra_people review_scores_cleanliness',
#   -0.48220349819515085),
#  ('bathrooms bedrooms^2 cleaning_fee', -0.4727325775993111),
#  ('host_response_rate guests_included review_scores_cleanliness not_superhost',
#   -0.46958396517492645),
#  ('host_response_rate guests_included^2 is_superhost', -0.4599551140240454),
#  ('bathrooms guests_included^3', -0.458916792947806),
#  ('accommodates bedrooms guests_included number_of_reviews',
#   -0.4522392809942467),
#  ('accommodates bedrooms extra_people review_scores_cleanliness',
#   -0.44937224611539706),
#  ('host_response_rate review_scores_cleanliness', -0.4446680695583098),
#  ('bedrooms review_scores_cleanliness^2 not_superhost', -0.44294353441581386),
#  ('accommodates bathrooms guests_included number_of_amenities',
#   -0.4376759895079487),
#  ('not_superhost^2', -0.43498626860797174),
#  ('beds^2 review_scores_cleanliness^2', -0.4341586502192012),
#  ('host_response_rate bedrooms^2', -0.43197277495240066),
#  ('bathrooms beds cleaning_fee not_superhost', -0.4308293897839427),
#  ('host_response_rate guests_included^2', -0.4304793537186692),
#  ('accommodates^3 bedrooms', -0.4275833569356863),
#  ('bathrooms^2 cleaning_fee review_scores_cleanliness', -0.426373419447952),
#  ('not_superhost^3', -0.424899570248309),
#  ('not_superhost^4', -0.42489798572357357),
#  ('bedrooms^2 number_of_reviews review_scores_cleanliness',
#   -0.4189253468129232),
#  ('bedrooms beds number_of_reviews review_scores_cleanliness',
#   -0.4176683101830788),
#  ('bedrooms^2 review_period', -0.4174404020172548),
#  ('accommodates bathrooms bedrooms number_of_reviews', -0.41741862641054245),
#  ('bathrooms extra_people number_of_amenities not_superhost',
#   -0.40586827908008427),
#  ('host_response_rate extra_people is_superhost', -0.39677003244447506),
#  ('host_response_rate extra_people is_superhost^2', -0.39647596404800217),
#  ('bathrooms bedrooms review_period is_superhost', -0.39525010091502943),
#  ('bedrooms^2 extra_people not_superhost', -0.39315504270737034),
#  ('beds^2 cleaning_fee', -0.3905987018691324),
#  ('security_deposit review_scores_cleanliness is_superhost^2',
#   -0.3840051573787085),
#  ('security_deposit review_scores_cleanliness is_superhost',
#   -0.38399264874579425),
#  ('accommodates guests_included extra_people is_superhost',
#   -0.3794012213435378),
#  ('bathrooms review_scores_cleanliness review_period not_superhost',
#   -0.3783406454193408),
#  ('security_deposit guests_included is_superhost^2', -0.37601890905995805),
#  ('security_deposit guests_included is_superhost', -0.3759760581699687),
#  ('review_scores_cleanliness^4', -0.375759341115992),
#  ('beds guests_included review_scores_cleanliness^2', -0.373423659484657),
#  ('cleaning_fee number_of_reviews', -0.3681600737564091),
#  ('bedrooms security_deposit guests_included', -0.3638673025989716),
#  ('bedrooms^2 cleaning_fee guests_included', -0.36119342038120233),
#  ('accommodates bedrooms beds number_of_reviews', -0.3597419437135535),
#  ('accommodates beds security_deposit', -0.3588199429103385),
#  ('guests_included^2 review_scores_cleanliness^2', -0.35854227427504143),
#  ('bathrooms^2 extra_people review_scores_cleanliness', -0.3546852295270198),
#  ('accommodates security_deposit is_superhost', -0.353075520513569),
#  ('accommodates security_deposit is_superhost^2', -0.35299846794850986),
#  ('bedrooms extra_people number_of_reviews', -0.3497328426712681),
#  ('bathrooms bedrooms cleaning_fee guests_included', -0.34581418653145635),
#  ('guests_included number_of_reviews number_of_amenities', -0.3455309978328136),
#  ('host_response_rate accommodates^2 not_superhost', -0.33811782039380883),
#  ('security_deposit review_scores_cleanliness', -0.3359426169351768),
#  ('accommodates^3 bathrooms', -0.33593846886449014),
#  ('cleaning_fee extra_people', -0.3345597783339336),
#  ('host_response_rate bedrooms^2 guests_included', -0.328375199670929),
#  ('number_of_reviews review_scores_cleanliness number_of_amenities',
#   -0.32387849545578395),
#  ('accommodates^2 number_of_reviews is_superhost', -0.3226561403824961),
#  ('bathrooms beds^2 number_of_reviews', -0.32139444525766486),
#  ('host_response_rate beds guests_included^2', -0.32077965204026254),
#  ('host_response_rate bedrooms guests_included is_superhost',
#   -0.3170102373857624),
#  ('beds extra_people^2', -0.31667277865123666),
#  ('beds number_of_amenities^2 is_superhost', -0.31664868424368375),
#  ('bathrooms cleaning_fee guests_included^2', -0.31006974924166564),
#  ('accommodates bedrooms cleaning_fee not_superhost', -0.30858207579597224),
#  ('accommodates bedrooms security_deposit', -0.30521633722307684),
#  ('beds review_scores_cleanliness number_of_amenities not_superhost',
#   -0.30361522821693465),
#  ('guests_included^2 review_period', -0.30069893991619234),
#  ('beds^2 cleaning_fee not_superhost', -0.3006306235928132),
#  ('bathrooms bedrooms security_deposit not_superhost', -0.29887412903032484),
#  ('cleaning_fee guests_included review_scores_cleanliness',
#   -0.29844157154377804),
#  ('beds number_of_amenities^2 not_superhost', -0.29608724670635744),
#  ('bathrooms cleaning_fee number_of_amenities is_superhost',
#   -0.29068177843062765),
#  ('beds cleaning_fee review_scores_cleanliness', -0.28939563806407737),
#  ('host_response_rate bathrooms extra_people is_superhost',
#   -0.2887633140047105),
#  ('beds cleaning_fee review_scores_cleanliness is_superhost',
#   -0.28872918349292237),
#  ('host_response_rate bedrooms^2 beds', -0.28840173062667046),
#  ('bathrooms review_scores_cleanliness review_period is_superhost',
#   -0.2869451363688089),
#  ('accommodates^2 number_of_reviews not_superhost', -0.28529619254513156),
#  ('beds^2 review_period', -0.2849167051956495),
#  ('accommodates beds guests_included extra_people', -0.28133238078563055),
#  ('cleaning_fee extra_people is_superhost^2', -0.2812687956496456),
#  ('cleaning_fee extra_people is_superhost', -0.28124026194652946),
#  ('cleaning_fee guests_included review_scores_cleanliness not_superhost',
#   -0.2763267565119319),
#  ('host_response_rate bedrooms beds', -0.27397040583965426),
#  ('host_response_rate bathrooms number_of_amenities is_superhost',
#   -0.26890369347761234),
#  ('accommodates beds review_scores_cleanliness number_of_amenities',
#   -0.2643636596316215),
#  ('bedrooms number_of_amenities^2', -0.26203168680769534),
#  ('beds^2 guests_included review_scores_cleanliness', -0.2572548041477615),
#  ('host_response_rate security_deposit is_superhost', -0.2526446266762747),
#  ('guests_included^2 review_scores_cleanliness number_of_amenities',
#   -0.25220807361083003),
#  ('host_response_rate rent_index', -0.2513897936675842),
#  ('beds guests_included^2 number_of_amenities', -0.250783461498247),
#  ('beds extra_people number_of_amenities', -0.2498374320111967),
#  ('host_response_rate security_deposit not_superhost', -0.24900111467265995),
#  ('host_response_rate security_deposit not_superhost^2', -0.24759364576670045),
#  ('host_response_rate security_deposit is_superhost^2', -0.2469801119927973),
#  ('bathrooms number_of_reviews review_scores_cleanliness^2',
#   -0.24653622465956773),
#  ('bathrooms guests_included^2 number_of_amenities', -0.2458029086378606),
#  ('guests_included^2 number_of_reviews review_scores_cleanliness',
#   -0.24495768953685793),
#  ('bathrooms bedrooms review_period not_superhost', -0.24430798388737723),
#  ('accommodates^2 bathrooms review_scores_cleanliness', -0.23842761274093727),
#  ('host_response_rate bedrooms beds^2', -0.23647956389819827),
#  ('bedrooms^2 review_period is_superhost', -0.236252347742491),
#  ('accommodates^2 cleaning_fee', -0.23360672706599886),
#  ('host_response_rate bathrooms guests_included review_scores_cleanliness',
#   -0.23317715584411308),
#  ('beds number_of_days_as_host', -0.22934925279883592),
#  ('host_response_rate number_of_reviews is_superhost', -0.22916391586175264),
#  ('host_response_rate bathrooms extra_people', -0.22914036126045445),
#  ('host_response_rate number_of_reviews is_superhost^2', -0.22778862733096256),
#  ('bathrooms bedrooms rent_index', -0.22419692941898875),
#  ('bedrooms review_scores_cleanliness^2 number_of_amenities',
#   -0.22231066476197892),
#  ('cleaning_fee guests_included', -0.22154295388730075),
#  ('bathrooms cleaning_fee number_of_amenities not_superhost',
#   -0.2196664699638048),
#  ('bedrooms^2 review_scores_cleanliness number_of_amenities',
#   -0.2165240959392879),
#  ('accommodates extra_people review_scores_cleanliness is_superhost',
#   -0.21528207396103713),
#  ('guests_included extra_people number_of_reviews', -0.21226363730315512),
#  ('accommodates^2 guests_included number_of_amenities', -0.21223724704858993),
#  ('bedrooms security_deposit is_superhost^2', -0.21063246220114276),
#  ('bedrooms security_deposit is_superhost', -0.21052281087495964),
#  ('number_of_reviews^2', -0.20622761664236391),
#  ('bedrooms cleaning_fee review_scores_cleanliness', -0.20139700265373317),
#  ('bathrooms bedrooms security_deposit', -0.20117730462364192),
#  ('bedrooms^2 security_deposit', -0.20110129744649125),
#  ('bedrooms rent_index is_superhost', -0.20017721635335098),
#  ('bedrooms rent_index is_superhost^2', -0.20011938443946775),
#  ('host_response_rate number_of_amenities not_superhost^2',
#   -0.19780962836860536),
#  ('host_response_rate number_of_amenities not_superhost', -0.1965925462249911),
#  ('accommodates beds security_deposit not_superhost', -0.19637967515644003),
#  ('host_response_rate bathrooms guests_included', -0.19631063960550418),
#  ('accommodates review_scores_cleanliness number_of_amenities not_superhost',
#   -0.19417775264896123),
#  ('bedrooms security_deposit guests_included is_superhost',
#   -0.19184050035817005),
#  ('guests_included number_of_reviews number_of_amenities not_superhost',
#   -0.19165868099371888),
#  ('bathrooms security_deposit guests_included', -0.19115491450395308),
#  ('cleaning_fee number_of_reviews is_superhost', -0.189098078419937),
#  ('cleaning_fee number_of_reviews is_superhost^2', -0.18909585123161984),
#  ('bathrooms bedrooms rent_index is_superhost', -0.188216039008047),
#  ('bathrooms rent_index not_superhost^2', -0.18800258707480283),
#  ('bathrooms rent_index not_superhost', -0.18799464979957448),
#  ('bathrooms bedrooms number_of_amenities^2', -0.18656075204280195),
#  ('host_response_rate review_scores_cleanliness not_superhost',
#   -0.18606870829009256),
#  ('host_response_rate review_scores_cleanliness not_superhost^2',
#   -0.18597862809796042),
#  ('accommodates^2 guests_included review_scores_cleanliness',
#   -0.1853960240149178),
#  ('bedrooms^2 review_period not_superhost', -0.18120080903021857),
#  ('bedrooms extra_people number_of_reviews not_superhost',
#   -0.17967063630146413),
#  ('beds^2 extra_people review_scores_cleanliness', -0.17813771961502392),
#  ('bedrooms number_of_reviews number_of_amenities', -0.1760011765928785),
#  ('bedrooms guests_included^2 extra_people', -0.17496349910495196),
#  ('host_response_rate bedrooms number_of_amenities not_superhost',
#   -0.1732649000337399),
#  ('bathrooms cleaning_fee guests_included is_superhost', -0.17266075551094037),
#  ('bedrooms security_deposit guests_included not_superhost',
#   -0.17211182838522884),
#  ('bedrooms extra_people number_of_reviews is_superhost', -0.17008295802990353),
#  ('guests_included^2 review_period not_superhost', -0.16979805690740307),
#  ('beds extra_people^2 is_superhost', -0.16938799434473056),
#  ('beds cleaning_fee guests_included^2', -0.1681275565784956),
#  ('bathrooms review_scores_cleanliness^3', -0.16767765607463278),
#  ('accommodates^2 bathrooms number_of_amenities', -0.16727544499159708),
#  ('accommodates bedrooms security_deposit not_superhost', -0.16519839727548857),
#  ('bedrooms^2 security_deposit is_superhost', -0.16455715940885798),
#  ('guests_included review_scores_cleanliness review_period',
#   -0.1641328449338224),
#  ('number_of_reviews review_scores_cleanliness number_of_amenities '
#   'is_superhost',
#   -0.16351974198341798),
#  ('bedrooms^3 extra_people', -0.16351100563683324),
#  ('accommodates bathrooms bedrooms cleaning_fee', -0.16344477671609775),
#  ('security_deposit guests_included', -0.16306781961026015),
#  ('accommodates beds security_deposit is_superhost', -0.16272585998201256),
#  ('accommodates extra_people review_scores_cleanliness', -0.16242634278718485),
#  ('cleaning_fee number_of_reviews not_superhost', -0.16222102067196179),
#  ('cleaning_fee number_of_reviews not_superhost^2', -0.16220703301466777),
#  ('number_of_reviews review_scores_cleanliness number_of_amenities '
#   'not_superhost',
#   -0.16035411991400159),
#  ('accommodates bathrooms number_of_amenities not_superhost',
#   -0.159469962051419),
#  ('bedrooms security_deposit', -0.15923430607592354),
#  ('guests_included number_of_reviews review_scores_cleanliness^2',
#   -0.15799436513531423),
#  ('extra_people number_of_reviews review_scores_cleanliness',
#   -0.1575215628685099),
#  ('bedrooms beds cleaning_fee review_scores_cleanliness', -0.15749563438237965),
#  ('beds security_deposit not_superhost', -0.15732429532163408),
#  ('beds security_deposit not_superhost^2', -0.15731488145220843),
#  ('host_response_rate accommodates extra_people', -0.15727610210718404),
#  ('accommodates bathrooms guests_included number_of_reviews',
#   -0.15688265537749008),
#  ('bedrooms number_of_amenities^2 is_superhost', -0.15592374065944425),
#  ('guests_included number_of_reviews number_of_amenities is_superhost',
#   -0.15387503722883805),
#  ('cleaning_fee^2', -0.15323869452555341),
#  ('accommodates security_deposit', -0.15058884255800517),
#  ('bathrooms guests_included number_of_reviews', -0.14997725152183053),
#  ('guests_included review_scores_cleanliness^2 number_of_amenities',
#   -0.14965357561696616),
#  ('accommodates beds cleaning_fee guests_included', -0.1488454021755308),
#  ('host_response_rate^2', -0.14747485836770177),
#  ('host_response_rate number_of_reviews not_superhost', -0.14742193873347162),
#  ('beds extra_people^2 not_superhost', -0.1472754215909345),
#  ('host_response_rate number_of_reviews not_superhost^2', -0.1470156207275676),
#  ('beds number_of_days_as_host not_superhost^2', -0.14666627804214616),
#  ('accommodates bathrooms rent_index', -0.14664571741961954),
#  ('beds number_of_days_as_host not_superhost', -0.1466248023240965),
#  ('review_scores_cleanliness rent_index is_superhost', -0.14645355679114816),
#  ('review_scores_cleanliness rent_index is_superhost^2', -0.14644803075134702),
#  ('beds^2 review_period is_superhost', -0.1445384850122084),
#  ('host_response_rate beds guests_included review_scores_cleanliness',
#   -0.14361296190998435),
#  ('host_response_rate^2 beds', -0.14304637371338091),
#  ('bedrooms^2 extra_people is_superhost', -0.1421571604835918),
#  ('bedrooms^3 cleaning_fee', -0.1418789338113021),
#  ('host_response_rate accommodates^2 bathrooms', -0.14186033047065172),
#  ('beds^2 guests_included number_of_reviews', -0.1405001514787034),
#  ('beds^2 review_period not_superhost', -0.14034075620563988),
#  ('beds number_of_reviews review_scores_cleanliness', -0.13986840171974052),
#  ('accommodates bedrooms security_deposit is_superhost', -0.13959653765686314),
#  ('host_response_rate review_scores_cleanliness^2 is_superhost',
#   -0.138150595080571),
#  ('extra_people^2', -0.13700219256533944),
#  ('accommodates bathrooms extra_people not_superhost', -0.13611296090626893),
#  ('host_response_rate accommodates bathrooms beds', -0.13538689362698164),
#  ('host_response_rate bathrooms bedrooms review_scores_cleanliness',
#   -0.13465938054510374),
#  ('bathrooms beds review_period', -0.13314111173743842),
#  ('beds extra_people number_of_amenities is_superhost', -0.13275896134090018),
#  ('guests_included number_of_days_as_host is_superhost', -0.13198200239530325),
#  ('guests_included number_of_days_as_host is_superhost^2', -0.1319728162277511),
#  ('host_response_rate accommodates extra_people not_superhost',
#   -0.13193615050085505),
#  ('guests_included^2 review_period is_superhost', -0.1308951598121368),
#  ('host_response_rate bedrooms^3', -0.1273786756753764),
#  ('bathrooms guests_included rent_index', -0.12620432722352876),
#  ('accommodates bathrooms number_of_reviews review_scores_cleanliness',
#   -0.12566820979064658),
#  ('bathrooms guests_included^2 number_of_reviews', -0.12472435285368771),
#  ('guests_included number_of_days_as_host', -0.12432514059638275),
#  ('host_response_rate accommodates number_of_reviews', -0.12363478920339148),
#  ('host_response_rate review_scores_cleanliness^2', -0.1231480822958539),
#  ('bathrooms^2 rent_index is_superhost', -0.12306237955547371),
#  ('accommodates^2 cleaning_fee is_superhost', -0.12166609505850917),
#  ('bedrooms^2 extra_people number_of_amenities', -0.12101414710756969),
# ...
#  ('beds^2 extra_people is_superhost', 2.5257258140966696),
#  ('review_scores_cleanliness number_of_amenities', 2.550190353610541),
#  ('bathrooms guests_included number_of_amenities', 2.5664561304017415),
#  ('accommodates guests_included^3', 2.568947131238879),
#  ('bathrooms beds review_scores_cleanliness^2', 2.5898335296665826),
#  ('accommodates guests_included^2 not_superhost', 2.6207486463184337),
#  ('beds guests_included^2 is_superhost', 2.662630856101217),
#  ('beds^2 number_of_reviews not_superhost', 2.700916782442837),
#  ('bathrooms bedrooms^2 number_of_amenities', 2.71550312014479),
#  ('bedrooms guests_included extra_people', 2.761320795335622),
#  ('bedrooms^2 review_scores_cleanliness not_superhost', 2.774641055391073),
#  ('bathrooms beds extra_people is_superhost', 2.784930102352263),
#  ('bedrooms review_scores_cleanliness^2 is_superhost', 2.789756274062552),
#  ('host_response_rate accommodates beds', 2.795648384051454),
#  ('beds^2 number_of_reviews is_superhost', 2.796768867432254),
#  ('bathrooms^2 number_of_amenities', 2.843354134504006),
#  ('beds guests_included extra_people is_superhost', 2.8456105357221326),
#  ('host_response_rate accommodates bathrooms', 2.8462022527799906),
#  ('bedrooms^2 number_of_reviews', 2.8625124240221083),
#  ('accommodates cleaning_fee', 2.9284017963041094),
#  ('host_response_rate bedrooms', 2.933359151510828),
#  ('bedrooms beds review_scores_cleanliness^2', 2.9893069469906153),
#  ('bathrooms number_of_reviews review_scores_cleanliness not_superhost',
#   3.0074928533647025),
#  ('bedrooms review_scores_cleanliness number_of_amenities', 3.0220367877825742),
#  ('review_scores_cleanliness^3 is_superhost', 3.0811548025872106),
#  ('bathrooms security_deposit not_superhost', 3.1392802838089406),
#  ('bathrooms security_deposit not_superhost^2', 3.1393448691615684),
#  ('accommodates bedrooms extra_people is_superhost', 3.1778283133309317),
#  ('bedrooms extra_people is_superhost', 3.178661923269494),
#  ('bedrooms extra_people is_superhost^2', 3.1786922456533406),
#  ('bedrooms guests_included', 3.178766518504165),
#  ('host_response_rate beds', 3.209578639337353),
#  ('beds cleaning_fee not_superhost^2', 3.2476814260250193),
#  ('beds cleaning_fee not_superhost', 3.247731488265883),
#  ('bathrooms^2 guests_included review_scores_cleanliness', 3.297787586463354),
#  ('host_response_rate guests_included not_superhost^2', 3.303739634661896),
#  ('host_response_rate guests_included not_superhost', 3.3041118339848534),
#  ('host_response_rate accommodates beds is_superhost', 3.3974974245955316),
#  ('bedrooms^2 beds review_scores_cleanliness', 3.4006928568583024),
#  ('bathrooms number_of_reviews review_scores_cleanliness is_superhost',
#   3.42337542348838),
#  ('beds cleaning_fee is_superhost', 3.4275481434646595),
#  ('beds cleaning_fee is_superhost^2', 3.4275792803668086),
#  ('guests_included^2', 3.5377209946548978),
#  ('accommodates^2 bathrooms beds', 3.5914831786308805),
#  ('bathrooms beds guests_included is_superhost', 3.5959755024460125),
#  ('accommodates beds number_of_amenities', 3.6006426270573315),
#  ('bathrooms beds number_of_reviews not_superhost', 3.63779764725006),
#  ('bedrooms beds number_of_amenities', 3.764712958829093),
#  ('accommodates bedrooms number_of_reviews', 3.8483408681252853),
#  ('beds^2 extra_people', 3.8787313007655024),
#  ('host_response_rate bathrooms bedrooms is_superhost', 3.9390574977375143),
#  ('bathrooms bedrooms beds guests_included', 3.9428730118205273),
#  ('beds guests_included^2', 3.9947803939763813),
#  ('accommodates^2 not_superhost', 4.022242043857732),
#  ('accommodates^2 not_superhost^2', 4.022620353647722),
#  ('guests_included^2 is_superhost^2', 4.150084141207602),
#  ('guests_included^2 is_superhost', 4.1501072233915925),
#  ('host_response_rate bedrooms not_superhost^2', 4.23282425537219),
#  ('host_response_rate bedrooms not_superhost', 4.2351846526908945),
#  ('bathrooms review_period', 4.348273847964072),
#  ('guests_included^2 number_of_amenities', 4.497727291153711),
#  ('bathrooms cleaning_fee not_superhost^2', 4.5228676087065045),
#  ('bathrooms cleaning_fee not_superhost', 4.5228823316872555),
#  ('bathrooms security_deposit', 4.62971328494924),
#  ('guests_included number_of_reviews review_scores_cleanliness',
#   4.697312621405397),
#  ('accommodates bedrooms extra_people', 4.78239835586001),
#  ('bathrooms beds extra_people', 4.86941521816888),
#  ('host_response_rate beds is_superhost^2', 4.896588744750407),
#  ('host_response_rate beds is_superhost', 4.900711398412692),
#  ('beds guests_included extra_people', 4.95385405025577),
#  ('bedrooms^2 guests_included^2', 5.076128832581586),
#  ('review_scores_cleanliness^3', 5.2200741168605616),
#  ('bedrooms beds guests_included^2', 5.246122045544217),
#  ('host_response_rate guests_included is_superhost^2', 5.33755986877696),
#  ('host_response_rate guests_included is_superhost', 5.338724281630857),
#  ('bathrooms beds number_of_reviews is_superhost', 5.379155639990004),
#  ('bedrooms^3 beds', 5.440809109566833),
#  ('beds^2 number_of_reviews', 5.497683302593733),
#  ('review_scores_cleanliness number_of_amenities is_superhost^2',
#   5.5086310563193575),
#  ('review_scores_cleanliness number_of_amenities is_superhost',
#   5.508643155831521),
#  ('accommodates number_of_reviews is_superhost', 5.530839779991968),
#  ('accommodates number_of_reviews is_superhost^2', 5.5310733156738126),
#  ('beds guests_included review_scores_cleanliness not_superhost',
#   5.566692191557148),
#  ('accommodates beds review_scores_cleanliness', 5.710339610573415),
#  ('accommodates bathrooms^2 guests_included', 5.712782768624263),
#  ('bedrooms guests_included^2 is_superhost', 5.713949560873434),
#  ('accommodates number_of_reviews not_superhost^2', 5.975688057729119),
#  ('accommodates number_of_reviews not_superhost', 5.97593916273562),
#  ('bathrooms bedrooms beds', 6.042645621203574),
#  ('host_response_rate bathrooms^2 is_superhost', 6.057075805801453),
#  ('accommodates bedrooms guests_included review_scores_cleanliness',
#   6.100251170127237),
#  ('bathrooms^4', 6.219675335908911),
#  ('bathrooms^2 beds', 6.253716451188876),
#  ('accommodates extra_people not_superhost^2', 6.327261524056582),
#  ('accommodates extra_people not_superhost', 6.327495990924986),
#  ('guests_included not_superhost^3', 6.376250005388054),
#  ('guests_included not_superhost^2', 6.376254322758209),
#  ('guests_included not_superhost', 6.385152140467825),
#  ('bedrooms guests_included^2', 6.403828229386586),
#  ('bathrooms number_of_reviews review_scores_cleanliness', 6.430779001949747),
#  ('host_response_rate bathrooms not_superhost^2', 6.671654998441574),
#  ('host_response_rate bathrooms not_superhost', 6.672287439169453),
#  ('beds cleaning_fee', 6.678461788005163),
#  ('host_response_rate bathrooms', 6.8128445591999185),
#  ('bedrooms^2 review_scores_cleanliness is_superhost', 6.90697527180252),
#  ('bathrooms guests_included review_scores_cleanliness', 7.055292992263595),
#  ('accommodates^2 bathrooms bedrooms', 7.2663398370568535),
#  ('bedrooms number_of_reviews not_superhost', 7.321097931573166),
#  ('bedrooms number_of_reviews not_superhost^2', 7.321144149808096),
#  ('accommodates beds review_scores_cleanliness not_superhost',
#   7.330702760584194),
#  ('accommodates^2 bedrooms not_superhost', 7.382971744098413),
#  ('accommodates bathrooms review_scores_cleanliness not_superhost',
#   7.804315500873596),
#  ('review_scores_cleanliness is_superhost^2', 8.383744445401522),
#  ('review_scores_cleanliness is_superhost^3', 8.38374549981903),
#  ('review_scores_cleanliness is_superhost', 8.385878027116902),
#  ('host_response_rate guests_included', 8.412394524960284),
#  ('bathrooms^2 bedrooms', 8.46845049630865),
#  ('accommodates review_scores_cleanliness not_superhost', 8.595333849641152),
#  ('accommodates review_scores_cleanliness not_superhost^2', 8.595547907402358),
#  ('bathrooms guests_included is_superhost^2', 8.754219460442453),
#  ('bathrooms guests_included is_superhost', 8.754247547116767),
#  ('bathrooms^2 bedrooms^2', 8.98485634418141),
#  ('bathrooms beds number_of_reviews', 9.016766707709658),
#  ('accommodates beds^2', 9.196595950631789),
#  ('accommodates extra_people', 9.391642293873588),
#  ('bedrooms number_of_reviews is_superhost^2', 9.445835288645032),
#  ('bedrooms number_of_reviews is_superhost', 9.445848529029655),
#  ('bedrooms^2 review_scores_cleanliness', 9.681584913848095),
#  ('bathrooms^2 beds^2', 9.767809122805216),
#  ('bedrooms guests_included review_scores_cleanliness not_superhost',
#   9.922636266175115),
#  ('bathrooms bedrooms beds review_scores_cleanliness', 10.04912380496956),
#  ('bedrooms beds^2 guests_included', 10.285852427692125),
#  ('bathrooms extra_people not_superhost', 10.636068872667492),
#  ('bathrooms extra_people not_superhost^2', 10.6361580461784),
#  ('accommodates bedrooms is_superhost^2', 10.670527682533107),
#  ('accommodates bedrooms is_superhost', 10.670794913920368),
#  ('accommodates beds^2 not_superhost', 10.819171242600426),
#  ('accommodates number_of_reviews', 10.834546807151007),
#  ('bedrooms review_scores_cleanliness is_superhost^2', 10.980780883738552),
#  ('bedrooms review_scores_cleanliness is_superhost', 10.980876988489143),
#  ('bathrooms^2 is_superhost^2', 11.42502308543006),
#  ('bathrooms^2 is_superhost', 11.425065174187544),
#  ('bathrooms bedrooms number_of_amenities is_superhost', 11.77676655977932),
#  ('bathrooms bedrooms number_of_amenities not_superhost', 12.682737153100575),
#  ('accommodates bathrooms^2 beds', 12.819699144410302),
#  ('bedrooms guests_included review_scores_cleanliness is_superhost',
#   13.239060330688469),
#  ('bedrooms^3 guests_included', 13.376768524385648),
#  ('accommodates^2 bathrooms not_superhost', 14.359038925035117),
#  ('accommodates bedrooms review_scores_cleanliness', 14.506903119903217),
#  ('bedrooms guests_included not_superhost^2', 14.55624432437397),
#  ('bedrooms guests_included not_superhost', 14.556246596864154),
#  ('bathrooms bedrooms is_superhost^2', 14.638986061253535),
#  ('bathrooms bedrooms is_superhost', 14.63912362839695),
#  ('bathrooms^2 guests_included^2', 14.889176471571046),
#  ('beds number_of_amenities not_superhost^2', 15.497006474523745),
#  ('beds number_of_amenities not_superhost', 15.497024289116377),
#  ('bathrooms^3 bedrooms', 15.533991120745517),
#  ('bathrooms guests_included not_superhost', 15.919836553826336),
#  ('bathrooms guests_included not_superhost^2', 15.919890357926672),
#  ('bedrooms number_of_amenities not_superhost', 16.10987382717045),
#  ('bedrooms number_of_amenities not_superhost^2', 16.10992236313975),
#  ('accommodates bedrooms^2 beds', 16.248793889914293),
#  ('accommodates bathrooms bedrooms guests_included', 16.344753516561745),
#  ('cleaning_fee is_superhost^2', 16.582121312214554),
#  ('cleaning_fee is_superhost^3', 16.58212192838802),
#  ('cleaning_fee is_superhost', 16.583614811467964),
#  ('bedrooms number_of_reviews', 16.830322894414454),
#  ('beds number_of_amenities is_superhost', 17.01307842083596),
#  ('beds number_of_amenities is_superhost^2', 17.013150707408027),
#  ('bedrooms number_of_amenities', 17.117302199346724),
#  ('number_of_reviews not_superhost', 17.311852294544067),
#  ('number_of_reviews not_superhost^3', 17.31485445968212),
#  ('number_of_reviews not_superhost^2', 17.31485719370413),
#  ('bathrooms guests_included review_scores_cleanliness not_superhost',
#   17.450788317715435),
#  ('beds guests_included not_superhost', 17.867261846776366),
#  ('beds guests_included not_superhost^2', 17.867337580820163),
#  ('accommodates bathrooms^2 is_superhost', 17.941931622024075),
#  ('cleaning_fee', 17.983973781347622),
#  ('bedrooms^3', 18.996136841440897),
#  ('accommodates^2 bathrooms is_superhost', 19.06487971919613),
#  ('bathrooms^2 bedrooms review_scores_cleanliness', 19.702043591369964),
#  ('bathrooms bedrooms guests_included^2', 19.86309470140464),
#  ('bathrooms beds^2 is_superhost', 19.953583791413305),
#  ('accommodates bedrooms review_scores_cleanliness is_superhost',
#   20.022368441328908),
#  ('bathrooms^3 guests_included', 21.156849279574644),
#  ('bathrooms bedrooms^3', 21.94267491944378),
#  ('bathrooms bedrooms beds not_superhost', 22.046551133488055),
#  ('bedrooms guests_included review_scores_cleanliness', 23.161588829552432),
#  ('accommodates bedrooms^2 is_superhost', 23.247850795158843),
#  ('beds guests_included review_scores_cleanliness is_superhost',
#   23.389863714153467),
#  ('bathrooms beds guests_included not_superhost', 23.627332990545938),
#  ('bathrooms bedrooms guests_included not_superhost', 24.237035050386535),
#  ('bathrooms bedrooms beds^2', 24.23925462440692),
#  ('bathrooms bedrooms number_of_amenities', 24.459546208235317),
#  ('number_of_reviews is_superhost', 24.526946938616273),
#  ('number_of_reviews is_superhost^2', 24.539818337699053),
#  ('number_of_reviews is_superhost^3', 24.539818457247144),
#  ('bathrooms guests_included', 24.670402840430338),
#  ('bathrooms extra_people is_superhost^2', 25.44655518105781),
#  ('bathrooms extra_people is_superhost', 25.446758502903826),
#  ('bathrooms beds guests_included', 27.22346601815896),
#  ('accommodates^2 is_superhost^2', 27.499162796350507),
#  ('accommodates^2 is_superhost', 27.499365575156688),
#  ('bathrooms bedrooms guests_included is_superhost', 27.72648911455414),
#  ('bedrooms^2 guests_included not_superhost', 28.273272956782463),
#  ('beds guests_included review_scores_cleanliness', 28.95656710330112),
#  ('bedrooms^2 guests_included is_superhost', 29.39331681638004),
#  ('beds review_scores_cleanliness', 29.40870171416052),
#  ('bedrooms^3 is_superhost', 29.63417223319806),
#  ('bedrooms beds^2 not_superhost', 29.727859353497177),
#  ('accommodates bathrooms is_superhost', 30.097694754683367),
#  ('accommodates bathrooms is_superhost^2', 30.09812907127397),
#  ('accommodates beds guests_included is_superhost', 30.198944587725748),
#  ('accommodates^2', 30.996584323241557),
#  ('beds number_of_amenities', 32.51925186071741),
#  ('accommodates beds guests_included not_superhost', 32.751433581533526),
#  ('accommodates bedrooms^2 not_superhost', 32.85727403820645),
#  ('bedrooms beds^2 is_superhost', 33.06632118921484),
#  ('accommodates^2 bathrooms', 33.42355996592846),
#  ('accommodates review_scores_cleanliness is_superhost^2', 33.913966793192955),
#  ('accommodates review_scores_cleanliness is_superhost', 33.91433551103096),
#  ('beds review_scores_cleanliness not_superhost^2', 34.0787453532528),
#  ('beds review_scores_cleanliness not_superhost', 34.07876803085892),
#  ('accommodates bathrooms bedrooms', 34.812550132481974),
#  ('bathrooms review_scores_cleanliness', 35.518075900501074),
#  ('bathrooms extra_people', 36.003511846032225),
#  ('bathrooms^2 beds not_superhost', 36.663686735603335),
#  ('accommodates beds not_superhost', 38.225151275213676),
#  ('accommodates beds not_superhost^2', 38.2261846786694),
#  ('bedrooms^2 is_superhost', 38.44183662357402),
#  ('bedrooms^2 is_superhost^2', 38.4418595665003),
#  ('bathrooms bedrooms^2', 39.60721600085645),
#  ('bathrooms^2 guests_included not_superhost', 41.205132763011854),
#  ('accommodates review_scores_cleanliness', 42.78382113214731),
#  ('number_of_reviews', 43.80016959054658),
#  ('number_of_amenities', 49.62529810378424),
#  ('bathrooms^2 bedrooms not_superhost', 50.6550274045668),
#  ('bathrooms bedrooms guests_included', 51.963144366303624),
#  ('number_of_amenities not_superhost^2', 55.31483314711448),
#  ('number_of_amenities not_superhost^3', 55.31483855146976),
#  ('number_of_amenities not_superhost', 55.31484191799437),
#  ('accommodates bedrooms^2', 56.10530468366607),
#  ('accommodates bathrooms bedrooms is_superhost', 56.820162119529606),
#  ('bedrooms^2 guests_included', 57.66650370448743),
#  ('bedrooms beds^2', 62.7941581392673),
#  ('accommodates beds guests_included', 62.9495978161575),
#  ('bathrooms beds review_scores_cleanliness is_superhost', 67.04661141008478),
#  ('bathrooms beds review_scores_cleanliness', 67.81647407411924),
#  ('bathrooms review_scores_cleanliness not_superhost^2', 71.43308216598768),
#  ('bathrooms review_scores_cleanliness not_superhost', 71.43313226571027),
#  ('bathrooms^2 guests_included is_superhost', 80.1868018440983),
#  ('bathrooms bedrooms^2 not_superhost', 83.04973699162159),
#  ('bathrooms^2 guests_included', 121.39207975527563)]

# %%
polynomial_predict_residual = Y_train.values - polynom_predict #polynom_predict is prediction values
plt.scatter(Y_train,polynomial_predict_residual, marker='+') #shows nonlinear pattern
plt.scatter(Y_train,Y_pred, marker='+') #shows nonlinear pattern
